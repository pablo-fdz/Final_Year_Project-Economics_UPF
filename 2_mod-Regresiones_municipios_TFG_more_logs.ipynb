# %% [markdown]
# # **Regresiones por municipios - modelo con más logs**

# %% [markdown]
# # 1. Importamos los paquetes y los datos necesarios

# %% [markdown]
# ### *Paquetes*

# %% [markdown]
# Importar paquetes.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %% [markdown]
# ### *Datos*

# %% [markdown]
# Importamos los datos en dos DataFrames, uno para cada tipo de vivienda. Son los datos a nivel de **municipio**.

# %%
df_noBCN_VC = pd.read_csv('/Users/pablo/Desktop/Drive pablo.fdzalb/6o curso/TFG economía/Datos/Regresiones - Modelos/Datasets/df_noBCN_VC_municip.csv')

df_noBCN_VU = pd.read_csv('/Users/pablo/Desktop/Drive pablo.fdzalb/6o curso/TFG economía/Datos/Regresiones - Modelos/Datasets/df_noBCN_VU_municip.csv')

# %%
df_noBCN_VC
# Out:
#     Unnamed: 0  CUMUN                       LITMUN  ALQM2mes_LV_M_VC_21  \
# 0            0   8015                     Badalona             9.221991
# 1            1   8020                       Begues             9.283657
# 2            2   8054                Castellbisbal             7.576446
# 3            3   8056                Castelldefels            11.561019
# 4            4   8068                     Cervelló             7.885955
# 5            5   8072         Corbera de Llobregat             7.281553
# 6            6   8073        Cornellà de Llobregat            10.235450
# 7            7   8077       Esplugues de Llobregat            11.524223
# 8            8   8089                         Gavà             9.792644
# 9            9   8101  Hospitalet de Llobregat, L'            11.620557
# 10          10   8123                Molins de Rei             8.827613
# 11          11   8125            Montcada i Reixac             7.977742
# 12          12   8126                      Montgat             9.698936
# 13          13   8157                      Pallejà             8.783784
# 14          14   8158                   Papiol, El             7.579846
# 15          15   8169        Prat de Llobregat, El             9.917891
# 16          16   8180                     Ripollet             8.395145
# 17          17   8194          Sant Adrià de Besòs             9.838483
# 18          18   8196      Sant Andreu de la Barca             7.809759
# 19          19   8200        Sant Boi de Llobregat             9.854274
# 20          20   8204    Sant Climent de Llobregat             9.092443
# 21          21   8205        Sant Cugat del Vallès            12.041768
# 22          22   8211      Sant Feliu de Llobregat            10.106738
# 23          23   8217              Sant Joan Despí            10.329927
# 24          24   8221            Sant Just Desvern            11.531429
# 25          25   8244     Santa Coloma de Cervelló             8.580659
# 26          26   8245     Santa Coloma de Gramenet             8.900525
# 27          27   8252           Barberà del Vallès             8.226827
# 28          28   8263       Sant Vicenç dels Horts             8.239519
# 29          29   8266        Cerdanyola del Vallès             9.110375
# 30          30   8282                        Tiana             9.935488
# 31          31   8289       Torrelles de Llobregat             8.593750
# 32          32   8301                   Viladecans             9.300533
# 33          33   8904             Badia del Vallès             6.353846
# 34          34   8905        Palma de Cervelló, La             8.256534
#
#     time_pub_trans  time_priv_trans  str_line_dist  has_tram  has_metro  \
# 0        33.162462        34.941060       8.611524         1          1
# 1        75.000000        55.000000      21.630000         0          0
# 2        73.000000        60.000000      18.710000         0          0
# 3        46.296728        41.330646      20.590545         0          0
# 4        55.000000        55.000000      17.980000         0          0
# 5        86.000000        60.000000      20.800000         0          0
# 6        25.058716        33.468550       8.342974         1          1
# 7        29.889485        31.967658       6.847914         1          1
# 8        47.820494        40.000000      16.754339         0          0
# 9        22.381607        27.585133       5.318290         1          1
# 10       38.688091        49.805918      12.927265         0          0
# 11       26.432625        42.223217      10.674630         0          1
# 12       26.000000        35.000000      13.190000         0          0
# 13       47.000000        45.000000      14.910000         0          0
# 14       45.000000        55.000000      14.490000         0          0
# 15       37.353150        28.230001       9.372313         0          1
# 16       45.646473        50.000000      12.546058         0          0
# 17       25.627677        31.554619       5.946972         1          1
# 18       45.000000        55.000000      17.790000         0          0
# 19       42.334581        36.904306      12.167804         0          0
# 20       62.000000        45.000000      15.470000         0          0
# 21       44.571373        46.999330      12.220257         0          0
# 22       33.348115        41.314620      10.317530         1          0
# 23       28.783723        37.437045       9.159586         1          0
# 24       38.000000        35.000000       8.040000         1          0
# 25       45.000000        45.000000      13.050000         0          0
# 26       31.462305        35.647486       7.901438         0          1
# 27       40.000000        35.000000      14.720000         0          0
# 28       48.956615        45.731863      13.772659         0          0
# 29       52.000000        50.000000      11.770000         0          0
# 30       44.000000        40.000000      13.010000         0          0
# 31       57.000000        55.000000      16.430000         0          0
# 32       49.190615        40.000000      15.205062         0          0
# 33       47.000000        50.000000      14.160000         0          0
# 34       67.000000        55.000000      17.020000         0          0
#
#     has_rodalies  ...  ibi_rur  cat_update  mob_estud  has_parks  \
# 0              1  ...   0.7990      1998.0   0.891922          1
# 1              0  ...   0.7100      2010.0   0.726937          1
# 2              0  ...   0.5150      2005.0   0.797131          1
# 3              1  ...   0.4200      2006.0   0.805291          1
# 4              0  ...   1.0000      2013.0   0.580128          1
# 5              0  ...   0.7700      1999.0   0.609259          1
# 6              1  ...   0.4660      2006.0   0.776492          1
# 7              1  ...   1.0100      1997.0   0.718048          1
# 8              1  ...   0.9000      2001.0   0.871301          1
# 9              1  ...   0.4300      2000.0   0.813806          1
# 10             1  ...   0.9000      2006.0   0.824710          1
# 11             1  ...   0.9000      2006.0   0.806130          1
# 12             1  ...   0.4400      2006.0   0.714286          1
# 13             0  ...   0.9000      2006.0   0.748837          1
# 14             1  ...   0.5200      2006.0   0.466216          1
# 15             1  ...   0.4490      1997.0   0.878596          1
# 16             0  ...   0.5580      2020.0   0.814588          0
# 17             1  ...   0.4000      2013.0   0.676910          1
# 18             0  ...   0.8680      1996.0   0.803940          1
# 19             0  ...   0.9820      2006.0   0.885745          1
# 20             0  ...   0.3000      2006.0   0.433962          1
# 21             0  ...   0.9000      2006.0   0.814825          0
# 22             1  ...   0.8370      2006.0   0.782899          1
# 23             1  ...   0.8800      2006.0   0.642419          1
# 24             0  ...   0.9000      1996.0   0.602170          1
# 25             0  ...   0.4500      2006.0   0.741935          1
# 26             0  ...   0.9000      2013.0   0.855187          1
# 27             1  ...   0.4700      1990.0   0.687243          1
# 28             0  ...   0.5200      2006.0   0.809524          1
# 29             0  ...   0.9000      2006.0   0.811692          0
# 30             0  ...   0.6500      2006.0   0.531646          1
# 31             0  ...   0.6130      1995.0   0.591304          0
# 32             1  ...   0.9763      2006.0   0.850964          1
# 33             1  ...   0.8400      2010.0   0.783654          1
# 34             0  ...   0.5000      1989.0   0.333333          0
#
#     rented_houses_mitma  industrial_waste   vpo  new_houses  parks_surface  \
# 0                 11168          15748.85  22.0         3.2   56811.224947
# 1                   378            224.76   0.0         1.9   10237.000000
# 2                   594         493377.58  17.0         1.9   14998.750000
# 3                  5221            311.89   7.0         0.6   43860.000000
# 4                   427           3222.28   0.0         2.3    7718.000000
# 5                   857            477.83   0.0         0.5    3624.000000
# 6                  5618          21819.17   0.0         3.7   73506.216694
# 7                  2653           7434.97   0.0         0.1   62683.705262
# 8                  2578          15742.80  30.0         1.7   59651.250000
# 9                 18815          28295.74  39.0         2.9   65532.909292
# 10                 1354           5750.57  15.0         5.6   41604.580000
# 11                 1671          44310.61   5.0         0.4   75663.123665
# 12                  587            245.43   0.0         5.6   61994.930000
# 13                  558            935.37   0.0         1.4    7410.070000
# 14                  241           8765.43   0.0         7.1    3691.330000
# 15                 2996          33501.49  43.0         1.9  139354.080840
# 16                 1895           7893.67   8.0         1.9   13325.090000
# 17                 1521           6818.75   4.0         7.7   44326.876452
# 18                 1382          21156.64   0.0         0.4   28488.000000
# 19                 4164          11830.84  11.0         1.2  255590.000000
# 20                  158             71.44   0.0         0.5   12979.000000
# 21                 5950          14470.89  14.0         4.7  106231.000000
# 22                 2444          15243.49  21.0         1.8   52035.799919
# 23                 1908           5010.73   4.0         5.4   96866.187612
# 24                 1012           2150.47   0.0         8.2   13936.000000
# 25                  294            263.09   0.0         0.4   32365.000000
# 26                 6812           2348.38  43.0         0.3   64879.687779
# 27                  923          23232.76   5.0         3.1   32347.000000
# 28                 1130           9652.10  12.0         0.6  118386.000000
# 29                 3412          12190.54   8.0         1.0  106231.000000
# 30                  423           3352.41   0.0        13.4   61994.930000
# 31                  337             92.40   0.0         0.3   12979.000000
# 32                 2943           4535.18  23.0         1.6   27237.943871
# 33                   43              0.00   2.0         0.0    8129.000000
# 34                  247             33.84   0.0         0.3   20842.000000
#
#     has_beach
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# 5           0
# 6           0
# 7           0
# 8           1
# 9           0
# 10          0
# 11          0
# 12          1
# 13          0
# 14          0
# 15          1
# 16          0
# 17          1
# 18          0
# 19          0
# 20          0
# 21          0
# 22          0
# 23          0
# 24          0
# 25          0
# 26          0
# 27          0
# 28          0
# 29          0
# 30          0
# 31          0
# 32          1
# 33          0
# 34          0
#
# [35 rows x 30 columns]

# %% [markdown]
# Aquí pondremos en logs los ***precios, avg_inc_hh y pop_density. Haré la ratio entre rented_houses_mitma y population (/100)***.
#
# La variable *ratio_rented_houses_population* tiene la siguiente interpretación: es el número de viviendas en alquiler (según los datos del MITMA) cada 100 habitantes, por distrito. De esta manera, representará mejor cuál es la oferta en cada distrito (ya que ni la población ni *rented_houses_mitma* aportaban ninguna información especialmente interesante por sí solas).

# %%
# Quitamos una columna que no sé qué pinta
df_noBCN_VC = df_noBCN_VC.drop(labels = ['Unnamed: 0'], axis = 1)

# Añado una columna con los precios, avg_inc_hh y pop_density en logs
df_noBCN_VC['log_ALQM2mes_LV_M_VC_21'] = np.log(df_noBCN_VC['ALQM2mes_LV_M_VC_21'])
df_noBCN_VC['log_avg_inc_hh'] = np.log(df_noBCN_VC['avg_inc_hh'])
df_noBCN_VC['log_pop_density'] = np.log(df_noBCN_VC['pop_density'])
# Hago una ratio de casas alquiladas / población
df_noBCN_VC['ratio_rented_houses_population'] = df_noBCN_VC['rented_houses_mitma'] / (df_noBCN_VC['population'] / 100)

df_noBCN_VC
# Out:
#     CUMUN                       LITMUN  ALQM2mes_LV_M_VC_21  time_pub_trans  \
# 0    8015                     Badalona             9.221991       33.162462
# 1    8020                       Begues             9.283657       75.000000
# 2    8054                Castellbisbal             7.576446       73.000000
# 3    8056                Castelldefels            11.561019       46.296728
# 4    8068                     Cervelló             7.885955       55.000000
# 5    8072         Corbera de Llobregat             7.281553       86.000000
# 6    8073        Cornellà de Llobregat            10.235450       25.058716
# 7    8077       Esplugues de Llobregat            11.524223       29.889485
# 8    8089                         Gavà             9.792644       47.820494
# 9    8101  Hospitalet de Llobregat, L'            11.620557       22.381607
# 10   8123                Molins de Rei             8.827613       38.688091
# 11   8125            Montcada i Reixac             7.977742       26.432625
# 12   8126                      Montgat             9.698936       26.000000
# 13   8157                      Pallejà             8.783784       47.000000
# 14   8158                   Papiol, El             7.579846       45.000000
# 15   8169        Prat de Llobregat, El             9.917891       37.353150
# 16   8180                     Ripollet             8.395145       45.646473
# 17   8194          Sant Adrià de Besòs             9.838483       25.627677
# 18   8196      Sant Andreu de la Barca             7.809759       45.000000
# 19   8200        Sant Boi de Llobregat             9.854274       42.334581
# 20   8204    Sant Climent de Llobregat             9.092443       62.000000
# 21   8205        Sant Cugat del Vallès            12.041768       44.571373
# 22   8211      Sant Feliu de Llobregat            10.106738       33.348115
# 23   8217              Sant Joan Despí            10.329927       28.783723
# 24   8221            Sant Just Desvern            11.531429       38.000000
# 25   8244     Santa Coloma de Cervelló             8.580659       45.000000
# 26   8245     Santa Coloma de Gramenet             8.900525       31.462305
# 27   8252           Barberà del Vallès             8.226827       40.000000
# 28   8263       Sant Vicenç dels Horts             8.239519       48.956615
# 29   8266        Cerdanyola del Vallès             9.110375       52.000000
# 30   8282                        Tiana             9.935488       44.000000
# 31   8289       Torrelles de Llobregat             8.593750       57.000000
# 32   8301                   Viladecans             9.300533       49.190615
# 33   8904             Badia del Vallès             6.353846       47.000000
# 34   8905        Palma de Cervelló, La             8.256534       67.000000
#
#     time_priv_trans  str_line_dist  has_tram  has_metro  has_rodalies  \
# 0         34.941060       8.611524         1          1             1
# 1         55.000000      21.630000         0          0             0
# 2         60.000000      18.710000         0          0             0
# 3         41.330646      20.590545         0          0             1
# 4         55.000000      17.980000         0          0             0
# 5         60.000000      20.800000         0          0             0
# 6         33.468550       8.342974         1          1             1
# 7         31.967658       6.847914         1          1             1
# 8         40.000000      16.754339         0          0             1
# 9         27.585133       5.318290         1          1             1
# 10        49.805918      12.927265         0          0             1
# 11        42.223217      10.674630         0          1             1
# 12        35.000000      13.190000         0          0             1
# 13        45.000000      14.910000         0          0             0
# 14        55.000000      14.490000         0          0             1
# 15        28.230001       9.372313         0          1             1
# 16        50.000000      12.546058         0          0             0
# 17        31.554619       5.946972         1          1             1
# 18        55.000000      17.790000         0          0             0
# 19        36.904306      12.167804         0          0             0
# 20        45.000000      15.470000         0          0             0
# 21        46.999330      12.220257         0          0             0
# 22        41.314620      10.317530         1          0             1
# 23        37.437045       9.159586         1          0             1
# 24        35.000000       8.040000         1          0             0
# 25        45.000000      13.050000         0          0             0
# 26        35.647486       7.901438         0          1             0
# 27        35.000000      14.720000         0          0             1
# 28        45.731863      13.772659         0          0             0
# 29        50.000000      11.770000         0          0             0
# 30        40.000000      13.010000         0          0             0
# 31        55.000000      16.430000         0          0             0
# 32        40.000000      15.205062         0          0             1
# 33        50.000000      14.160000         0          0             1
# 34        55.000000      17.020000         0          0             0
#
#     has_fgc  ...  rented_houses_mitma  industrial_waste   vpo  new_houses  \
# 0         0  ...                11168          15748.85  22.0         3.2
# 1         0  ...                  378            224.76   0.0         1.9
# 2         0  ...                  594         493377.58  17.0         1.9
# 3         0  ...                 5221            311.89   7.0         0.6
# 4         0  ...                  427           3222.28   0.0         2.3
# 5         0  ...                  857            477.83   0.0         0.5
# 6         1  ...                 5618          21819.17   0.0         3.7
# 7         0  ...                 2653           7434.97   0.0         0.1
# 8         0  ...                 2578          15742.80  30.0         1.7
# 9         1  ...                18815          28295.74  39.0         2.9
# 10        0  ...                 1354           5750.57  15.0         5.6
# 11        0  ...                 1671          44310.61   5.0         0.4
# 12        0  ...                  587            245.43   0.0         5.6
# 13        1  ...                  558            935.37   0.0         1.4
# 14        0  ...                  241           8765.43   0.0         7.1
# 15        0  ...                 2996          33501.49  43.0         1.9
# 16        0  ...                 1895           7893.67   8.0         1.9
# 17        0  ...                 1521           6818.75   4.0         7.7
# 18        1  ...                 1382          21156.64   0.0         0.4
# 19        1  ...                 4164          11830.84  11.0         1.2
# 20        0  ...                  158             71.44   0.0         0.5
# 21        1  ...                 5950          14470.89  14.0         4.7
# 22        0  ...                 2444          15243.49  21.0         1.8
# 23        0  ...                 1908           5010.73   4.0         5.4
# 24        0  ...                 1012           2150.47   0.0         8.2
# 25        1  ...                  294            263.09   0.0         0.4
# 26        0  ...                 6812           2348.38  43.0         0.3
# 27        0  ...                  923          23232.76   5.0         3.1
# 28        1  ...                 1130           9652.10  12.0         0.6
# 29        0  ...                 3412          12190.54   8.0         1.0
# 30        0  ...                  423           3352.41   0.0        13.4
# 31        0  ...                  337             92.40   0.0         0.3
# 32        0  ...                 2943           4535.18  23.0         1.6
# 33        0  ...                   43              0.00   2.0         0.0
# 34        0  ...                  247             33.84   0.0         0.3
#
#     parks_surface  has_beach  log_ALQM2mes_LV_M_VC_21  log_avg_inc_hh  \
# 0    56811.224947          1                 2.221591       10.459179
# 1    10237.000000          0                 2.228256       10.919642
# 2    14998.750000          0                 2.025044       10.663195
# 3    43860.000000          1                 2.447639       10.733410
# 4     7718.000000          0                 2.065083       10.728847
# 5     3624.000000          0                 1.985344       10.724148
# 6    73506.216694          0                 2.325857       10.454466
# 7    62683.705262          0                 2.444451       10.649697
# 8    59651.250000          1                 2.281631       10.610165
# 9    65532.909292          0                 2.452776       10.389130
# 10   41604.580000          0                 2.177885       10.683278
# 11   75663.123665          0                 2.076655       10.498486
# 12   61994.930000          1                 2.272016       10.657589
# 13    7410.070000          0                 2.172907       10.714129
# 14    3691.330000          0                 2.025493       10.601299
# 15  139354.080840          1                 2.294340       10.522191
# 16   13325.090000          0                 2.127654       10.450625
# 17   44326.876452          1                 2.286302       10.367669
# 18   28488.000000          0                 2.055374       10.540699
# 19  255590.000000          0                 2.287905       10.504727
# 20   12979.000000          0                 2.207444       10.710075
# 21  106231.000000          0                 2.488381       11.113521
# 22   52035.799919          0                 2.313202       10.654550
# 23   96866.187612          0                 2.335045       10.712874
# 24   13936.000000          0                 2.445076       10.991999
# 25   32365.000000          0                 2.149511       10.786511
# 26   64879.687779          0                 2.186110       10.342963
# 27   32347.000000          0                 2.107400       10.577605
# 28  118386.000000          0                 2.108942       10.540715
# 29  106231.000000          0                 2.209414       10.664807
# 30   61994.930000          0                 2.296113       10.960618
# 31   12979.000000          0                 2.151035       10.757775
# 32   27237.943871          1                 2.230072       10.569651
# 33    8129.000000          0                 1.849060       10.280313
# 34   20842.000000          0                 2.111005       10.735592
#
#     log_pop_density  ratio_rented_houses_population
# 0          9.261898                        5.036302
# 1          4.982236                        5.139361
# 2          6.007338                        4.716157
# 3          8.560923                        7.808154
# 4          5.948296                        4.633749
# 5          6.704047                        5.702309
# 6          9.455277                        6.301173
# 7          9.227089                        5.762506
# 8          7.330536                        5.505841
# 9          9.968493                        7.099920
# 10         7.400987                        5.183172
# 11         7.357365                        4.533247
# 12         8.345954                        4.791837
# 13         7.245584                        4.793814
# 14         6.158884                        5.700095
# 15         7.643147                        4.579849
# 16         9.109304                        4.852132
# 17         9.186048                        4.097411
# 18         8.505303                        5.079762
# 19         8.268988                        4.979610
# 20         5.960748                        3.762801
# 21         7.575174                        6.428541
# 22         8.254867                        5.378639
# 23         8.618232                        5.599906
# 24         7.816538                        5.249235
# 25         7.007148                        3.547725
# 26         9.743395                        5.749057
# 27         8.287277                        2.794260
# 28         8.033594                        4.018492
# 29         7.534923                        5.950990
# 30         7.032801                        4.686981
# 31         6.113240                        5.505636
# 32         8.092545                        4.405029
# 33         9.562665                        0.323820
# 34         6.313910                        8.192371
#
# [35 rows x 33 columns]

# %%
# Quitamos una columna que no sé qué pinta
df_noBCN_VU = df_noBCN_VU.drop(labels = ['Unnamed: 0'], axis = 1)

# Añado una columna con los precios, avg_inc_hh y pop_density en logs
df_noBCN_VU['log_ALQM2mes_LV_M_VU_21'] = np.log(df_noBCN_VU['ALQM2mes_LV_M_VU_21'])
df_noBCN_VU['log_avg_inc_hh'] = np.log(df_noBCN_VU['avg_inc_hh'])
df_noBCN_VU['log_pop_density'] = np.log(df_noBCN_VU['pop_density'])
# Hago una ratio de casas alquiladas / población
df_noBCN_VU['ratio_rented_houses_population'] = df_noBCN_VU['rented_houses_mitma'] / (df_noBCN_VU['population'] / 100)

df_noBCN_VU
# Out:
#     CUMUN                       LITMUN  ALQM2mes_LV_M_VU_21  time_pub_trans  \
# 0    8015                     Badalona             5.372441       33.162462
# 1    8020                       Begues             7.241620       75.000000
# 2    8054                Castellbisbal             6.819341       73.000000
# 3    8056                Castelldefels            11.941936       46.296728
# 4    8068                     Cervelló             6.607143       55.000000
# 5    8072         Corbera de Llobregat             6.207310       86.000000
# 6    8073        Cornellà de Llobregat             8.118825       25.058716
# 7    8077       Esplugues de Llobregat            12.535144       29.889485
# 8    8089                         Gavà             8.252999       47.820494
# 9    8101  Hospitalet de Llobregat, L'             6.273387       22.381607
# 10   8123                Molins de Rei             6.213593       38.688091
# 11   8125            Montcada i Reixac             5.557134       26.432625
# 12   8126                      Montgat             8.585334       26.000000
# 13   8157                      Pallejà             6.952833       47.000000
# 14   8158                   Papiol, El             5.843753       45.000000
# 15   8169        Prat de Llobregat, El             4.697177       37.353150
# 16   8180                     Ripollet             5.035178       45.646473
# 17   8194          Sant Adrià de Besòs             6.446256       25.627677
# 18   8196      Sant Andreu de la Barca             6.608246       45.000000
# 19   8200        Sant Boi de Llobregat             6.829393       42.334581
# 20   8204    Sant Climent de Llobregat             6.240745       62.000000
# 21   8205        Sant Cugat del Vallès             9.989521       44.571373
# 22   8211      Sant Feliu de Llobregat             6.683922       33.348115
# 23   8217              Sant Joan Despí            10.718266       28.783723
# 24   8221            Sant Just Desvern            10.902256       38.000000
# 25   8244     Santa Coloma de Cervelló             7.681052       45.000000
# 26   8245     Santa Coloma de Gramenet             6.434112       31.462305
# 27   8252           Barberà del Vallès             5.686275       40.000000
# 28   8263       Sant Vicenç dels Horts             6.866793       48.956615
# 29   8266        Cerdanyola del Vallès             7.858295       52.000000
# 30   8282                        Tiana             7.389119       44.000000
# 31   8289       Torrelles de Llobregat             6.646586       57.000000
# 32   8301                   Viladecans             6.320369       49.190615
# 33   8905        Palma de Cervelló, La             6.275096       67.000000
#
#     time_priv_trans  str_line_dist  has_tram  has_metro  has_rodalies  \
# 0         34.941060       8.611524         1          1             1
# 1         55.000000      21.630000         0          0             0
# 2         60.000000      18.710000         0          0             0
# 3         41.330646      20.590545         0          0             1
# 4         55.000000      17.980000         0          0             0
# 5         60.000000      20.800000         0          0             0
# 6         33.468550       8.342974         1          1             1
# 7         31.967658       6.847914         1          1             1
# 8         40.000000      16.754339         0          0             1
# 9         27.585133       5.318290         1          1             1
# 10        49.805918      12.927265         0          0             1
# 11        42.223217      10.674630         0          1             1
# 12        35.000000      13.190000         0          0             1
# 13        45.000000      14.910000         0          0             0
# 14        55.000000      14.490000         0          0             1
# 15        28.230001       9.372313         0          1             1
# 16        50.000000      12.546058         0          0             0
# 17        31.554619       5.946972         1          1             1
# 18        55.000000      17.790000         0          0             0
# 19        36.904306      12.167804         0          0             0
# 20        45.000000      15.470000         0          0             0
# 21        46.999330      12.220257         0          0             0
# 22        41.314620      10.317530         1          0             1
# 23        37.437045       9.159586         1          0             1
# 24        35.000000       8.040000         1          0             0
# 25        45.000000      13.050000         0          0             0
# 26        35.647486       7.901438         0          1             0
# 27        35.000000      14.720000         0          0             1
# 28        45.731863      13.772659         0          0             0
# 29        50.000000      11.770000         0          0             0
# 30        40.000000      13.010000         0          0             0
# 31        55.000000      16.430000         0          0             0
# 32        40.000000      15.205062         0          0             1
# 33        55.000000      17.020000         0          0             0
#
#     has_fgc  ...  rented_houses_mitma  industrial_waste   vpo  new_houses  \
# 0         0  ...                11168          15748.85  22.0         3.2
# 1         0  ...                  378            224.76   0.0         1.9
# 2         0  ...                  594         493377.58  17.0         1.9
# 3         0  ...                 5221            311.89   7.0         0.6
# 4         0  ...                  427           3222.28   0.0         2.3
# 5         0  ...                  857            477.83   0.0         0.5
# 6         1  ...                 5618          21819.17   0.0         3.7
# 7         0  ...                 2653           7434.97   0.0         0.1
# 8         0  ...                 2578          15742.80  30.0         1.7
# 9         1  ...                18815          28295.74  39.0         2.9
# 10        0  ...                 1354           5750.57  15.0         5.6
# 11        0  ...                 1671          44310.61   5.0         0.4
# 12        0  ...                  587            245.43   0.0         5.6
# 13        1  ...                  558            935.37   0.0         1.4
# 14        0  ...                  241           8765.43   0.0         7.1
# 15        0  ...                 2996          33501.49  43.0         1.9
# 16        0  ...                 1895           7893.67   8.0         1.9
# 17        0  ...                 1521           6818.75   4.0         7.7
# 18        1  ...                 1382          21156.64   0.0         0.4
# 19        1  ...                 4164          11830.84  11.0         1.2
# 20        0  ...                  158             71.44   0.0         0.5
# 21        1  ...                 5950          14470.89  14.0         4.7
# 22        0  ...                 2444          15243.49  21.0         1.8
# 23        0  ...                 1908           5010.73   4.0         5.4
# 24        0  ...                 1012           2150.47   0.0         8.2
# 25        1  ...                  294            263.09   0.0         0.4
# 26        0  ...                 6812           2348.38  43.0         0.3
# 27        0  ...                  923          23232.76   5.0         3.1
# 28        1  ...                 1130           9652.10  12.0         0.6
# 29        0  ...                 3412          12190.54   8.0         1.0
# 30        0  ...                  423           3352.41   0.0        13.4
# 31        0  ...                  337             92.40   0.0         0.3
# 32        0  ...                 2943           4535.18  23.0         1.6
# 33        0  ...                  247             33.84   0.0         0.3
#
#     parks_surface  has_beach  log_ALQM2mes_LV_M_VU_21  log_avg_inc_hh  \
# 0    56811.224947          1                 1.681282       10.459179
# 1    10237.000000          0                 1.979845       10.919642
# 2    14998.750000          0                 1.919763       10.663195
# 3    43860.000000          1                 2.480056       10.733410
# 4     7718.000000          0                 1.888151       10.728847
# 5     3624.000000          0                 1.825728       10.724148
# 6    73506.216694          0                 2.094185       10.454466
# 7    62683.705262          0                 2.528536       10.649697
# 8    59651.250000          1                 2.110577       10.610165
# 9    65532.909292          0                 1.836316       10.389130
# 10   41604.580000          0                 1.826739       10.683278
# 11   75663.123665          0                 1.715082       10.498486
# 12   61994.930000          1                 2.150055       10.657589
# 13    7410.070000          0                 1.939149       10.714129
# 14    3691.330000          0                 1.765373       10.601299
# 15  139354.080840          1                 1.546962       10.522191
# 16   13325.090000          0                 1.616449       10.450625
# 17   44326.876452          1                 1.863500       10.367669
# 18   28488.000000          0                 1.888318       10.540699
# 19  255590.000000          0                 1.921236       10.504727
# 20   12979.000000          0                 1.831100       10.710075
# 21  106231.000000          0                 2.301537       11.113521
# 22   52035.799919          0                 1.899705       10.654550
# 23   96866.187612          0                 2.371949       10.712874
# 24   13936.000000          0                 2.388970       10.991999
# 25   32365.000000          0                 2.038756       10.786511
# 26   64879.687779          0                 1.861614       10.342963
# 27   32347.000000          0                 1.738055       10.577605
# 28  118386.000000          0                 1.926697       10.540715
# 29  106231.000000          0                 2.061570       10.664807
# 30   61994.930000          0                 2.000009       10.960618
# 31   12979.000000          0                 1.894103       10.757775
# 32   27237.943871          1                 1.843778       10.569651
# 33   20842.000000          0                 1.836589       10.735592
#
#     log_pop_density  ratio_rented_houses_population
# 0          9.261898                        5.036302
# 1          4.982236                        5.139361
# 2          6.007338                        4.716157
# 3          8.560923                        7.808154
# 4          5.948296                        4.633749
# 5          6.704047                        5.702309
# 6          9.455277                        6.301173
# 7          9.227089                        5.762506
# 8          7.330536                        5.505841
# 9          9.968493                        7.099920
# 10         7.400987                        5.183172
# 11         7.357365                        4.533247
# 12         8.345954                        4.791837
# 13         7.245584                        4.793814
# 14         6.158884                        5.700095
# 15         7.643147                        4.579849
# 16         9.109304                        4.852132
# 17         9.186048                        4.097411
# 18         8.505303                        5.079762
# 19         8.268988                        4.979610
# 20         5.960748                        3.762801
# 21         7.575174                        6.428541
# 22         8.254867                        5.378639
# 23         8.618232                        5.599906
# 24         7.816538                        5.249235
# 25         7.007148                        3.547725
# 26         9.743395                        5.749057
# 27         8.287277                        2.794260
# 28         8.033594                        4.018492
# 29         7.534923                        5.950990
# 30         7.032801                        4.686981
# 31         6.113240                        5.505636
# 32         8.092545                        4.405029
# 33         6.313910                        8.192371
#
# [34 rows x 33 columns]

# %% [markdown]
# # 2. Función para realizar las regresiones

# %% [markdown]
# Ahora voy a crear una función para hacer más rápidamente las regresiones.
#
# Para controlar heteroskedasticity-robust standard errors, hay un parámetro de OLS.fit() que se llama "cov_type" (https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.RegressionResults.html) que puede tomar, como valor, HC3 ("MacKinnon and White's (1985) heteroskedasticity robust standard errors").

# %%
# Función para hacer una regresión con los heteroskedasticity-robust standard errors
# Inputs:
## y = dependent variable
## x = list of explanatory variables
## df = DataFrame used for the regression

def lr(y, x, df):
    # First, we define the formula that will be used in the regression. We will construct it dynamically
    formula = f"{y} ~ {' + '.join(x)}"
    model = sm.OLS.from_formula(formula, data = df)
    results = model.fit(cov_type = 'HC3')
    print(results.summary())

# %% [markdown]
# # 3. Wrapper methods - machine learning
# Now I will use some wrapper methods for feature selection in order to choose a smaller number of features.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %% [markdown]
# ## a. *Standardizing the data*

# %% [markdown]
# First, we need to standardize the data. I will not standardize the dummy variables, which already are on a consistent scale (0 or 1). I have looked to several resources which advise against standardizing dummy variables, even if they're to be provided to a machine learning model: https://stats.stackexchange.com/questions/59392/should-you-ever-standardise-binary-variables; https://www.researchgate.net/post/Can_we_standardize_normalize_categorical_variables; https://stackoverflow.com/questions/50557129/dummy-variables-is-necessary-to-standardize-them; https://www.quora.com/How-bad-is-it-to-standardize-dummy-variables
#
# Therefore, below I will standardize only the quantitative variables.

# %%
print(df_noBCN_VC.columns)
# Out:
# Index(['CUMUN', 'LITMUN', 'ALQM2mes_LV_M_VC_21', 'time_pub_trans',
#        'time_priv_trans', 'str_line_dist', 'has_tram', 'has_metro',
#        'has_rodalies', 'has_fgc', 'pt_lines', 'population',
#        'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate',
#        'avg_inc_hh', 'population_growth', 'pop_density', 'ibi_urb', 'ibi_rur',
#        'cat_update', 'mob_estud', 'has_parks', 'rented_houses_mitma',
#        'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'has_beach',
#        'log_ALQM2mes_LV_M_VC_21', 'log_avg_inc_hh', 'log_pop_density',
#        'ratio_rented_houses_population'],
#       dtype='object')

# %%
# COLLECTIVE DWELLINGS

quant_variables_VC = list(df_noBCN_VC.columns[3:-1])
# Eliminamos las dummies de la lista de variables cuantitativas
quant_variables_VC.remove('has_beach')
quant_variables_VC.remove('has_parks')
quant_variables_VC.remove('has_tram')
quant_variables_VC.remove('has_metro')
quant_variables_VC.remove('has_rodalies')
quant_variables_VC.remove('has_fgc')
# Eliminamos las variables que no han sido transformadas y que no utilizaremos
quant_variables_VC.remove('population')
quant_variables_VC.remove('avg_inc_hh')
quant_variables_VC.remove('pop_density')
quant_variables_VC.remove('rented_houses_mitma')
# Eliminamos la variable dependiente de la lista
quant_variables_VC.remove('log_ALQM2mes_LV_M_VC_21')
# Eliminamos cat_update, que no proporciona ninguna información relevante
quant_variables_VC.remove('cat_update')
# Añadimos la última columna
quant_variables_VC.append('ratio_rented_houses_population')

# SINGLE-FAMILY DWELLINGS

quant_variables_VU = list(df_noBCN_VU.columns[3:-1])
# Eliminamos las dummies de la lista de variables cuantitativas
quant_variables_VU.remove('has_beach')
quant_variables_VU.remove('has_parks')
quant_variables_VU.remove('has_tram')
quant_variables_VU.remove('has_metro')
quant_variables_VU.remove('has_rodalies')
quant_variables_VU.remove('has_fgc')
# Eliminamos las variables que no han sido transformadas y que no utilizaremos
quant_variables_VU.remove('population')
quant_variables_VU.remove('avg_inc_hh')
quant_variables_VU.remove('pop_density')
quant_variables_VU.remove('rented_houses_mitma')
# Eliminamos la variable dependiente de la lista
quant_variables_VU.remove('log_ALQM2mes_LV_M_VU_21')
# Eliminamos cat_update, que no proporciona ninguna información relevante
quant_variables_VU.remove('cat_update')
# Añadimos la última columna
quant_variables_VU.append('ratio_rented_houses_population')

print(quant_variables_VC)
print(quant_variables_VU)

print(len(quant_variables_VC))
print(len(quant_variables_VU))
# Everything is okay, there are 18 explanatory variables in each list (26 explanatory variables - 6 dummies - 1 variable lost with ratio_rented_houses_population - cat_update)
# Out:
# ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population']
# ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population']
# 18
# 18

# %%
dummy_variables = ['has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# I have entered them in the same order as they are in the DataFrames

# %% [markdown]
# Then, the list below will have the feature names **in the order they have been introduced to the regression model below**.

# %%
print(quant_variables_VC + dummy_variables)
print(quant_variables_VU + dummy_variables)

print(len(quant_variables_VC + dummy_variables))
print(len(quant_variables_VU + dummy_variables))
# Out:
# ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# 24
# 24

# %% [markdown]
# Now, we standardize the data.

# %%
scaler = StandardScaler()

## COLLECTIVE DWELLINGS

# We standardize the data for the quantitative explanatory variables of collective dwellings
quant_vars_scaler_VC = scaler.fit_transform(df_noBCN_VC[quant_variables_VC])

# Now we concatenate the standardized quantitative variables and dummy variables for collective dwellings
standardized_vars_VC = np.concatenate((quant_vars_scaler_VC, df_noBCN_VC[dummy_variables]), axis = 1)

## SINGLE-FAMILY DWELLINGS

# We standardize the data for the quantitative explanatory variables of single-family dwellings
quant_vars_scaler_VU = scaler.fit_transform(df_noBCN_VU[quant_variables_VU])

# Now we concatenate the standardized quantitative variables and dummy variables for collective dwellings
standardized_vars_VU = np.concatenate((quant_vars_scaler_VU, df_noBCN_VU[dummy_variables]), axis = 1)

# %% [markdown]
# ## b. *Linear regression model with the standardized variables*

# %%
# For collective dwellings
mlr_VC = LinearRegression()
mlr_VC.fit(standardized_vars_VC, df_noBCN_VC['log_ALQM2mes_LV_M_VC_21'])

# For single-family dwellings
mlr_VU = LinearRegression()
mlr_VU.fit(standardized_vars_VU, df_noBCN_VU['log_ALQM2mes_LV_M_VU_21'])
# Out:
# LinearRegression()

# %% [markdown]
# ## c. *Wrapper methods*

# %% [markdown]
# First, I will create a function for computing the adjusted R-squared. I have computed the **adjusted R-squared** for each regression using the formula in Wikipedia (https://en.wikipedia.org/wiki/Coefficient_of_determination#Adjusted_R2):
#
# ![Captura de pantalla 2023-11-22 a las 15.04.30.png](<attachment:Captura de pantalla 2023-11-22 a las 15.04.30.png>)
#
# *where p is the total number of explanatory variables in the model,and n is the sample size*. "Unlike R2, the adjusted R2 increases only when the increase in R2 (due to the inclusion of a new explanatory variable) is more than one would expect to see by chance. If a set of explanatory variables with a predetermined hierarchy of importance are introduced into a regression one at a time, with the adjusted R2 computed each time, **the level at which adjusted R2 reaches a maximum, and decreases afterward, would be the regression with the ideal combination of having the best fit without excess/unnecessary terms**. " Furthermore, it is said in the article that "[a]djusted R2 is more appropriate when evaluating model fit (the variance in the dependent variable accounted for by the independent variables) and in comparing alternative models in the **feature selection** stage of model building."

# %%
# Inputs: 
## R2: R-squared of a regression
## n: sample size
## p: total number of explanatory variables in the model

def adjusted_R2(R2, n, p):
    adj_R2 = 1 - (1 - R2) * ((n - 1) / (n - p - 1))
    return adj_R2

# %% [markdown]
# ### i. **Recursive Feature Elimination**

# %%
from sklearn.feature_selection import RFE

# %% [markdown]
# **In the loops below, I will save the most relevant features for a certain number of selected features, for both collective and single-family dwellings**.
#
# Furthermore, we create a list comprehension and *rfe.support_* in order to get a list of chosen feature names.
#
# - Note from ChatGPT about whether the order of the data in the Numpy concatenation when creating *standardized_vars_VC* corresponds to the order in the list *quant_variables_VC + dummy_variables*: when you concatenate the standardized quantitative variables with the dummy variables using *np.concatenate((quant_vars_scaler_VC, df_noBCN_VC[dummy_variables]), axis=1)*, the order of the columns in the resulting *standardized_vars_VC* array corresponds to the order of variables in the list *quant_variables_VC + dummy_variables*.
#     So, when you later use this concatenated array in the RFE process and retrieve the feature names using the list comprehension, **the order is maintained**. The features in the resulting list *rfe_VC_features* will correspond to the order in which they appear in the concatenated array, which is the same order as in the list *quant_variables_VC + dummy_variables*.
# - Note from ChatGPT of the *score* method after having performed RFE: For regression tasks, such as predicting a continuous variable like *log_ALQM2mes_LV_M_VC_21*, **the default scoring metric is the coefficient of determination (R^2)**. The R^2 score is a measure of how well the predicted values match the actual values. It ranges from 0 to 1, with 1 indicating perfect predictions and 0 indicating that the model is no better than predicting the mean of the target variable. See also https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.score

# %%
# COLLECTIVE DWELLINGS

## In these empty lists I will save the score of each regression and the adjusted R-squared
score_VC = []
adjusted_R_squared_VC = []

# I will perform RFE for 1 to 24 features (we have 24 explanatory variables overall)
for n in range(1, len(quant_variables_VC + dummy_variables) + 1):
    rfe_VC = RFE(mlr_VC, n_features_to_select = n)
    # We perform RFE for the explanatory and dependent variables
    rfe_VC.fit(standardized_vars_VC, df_noBCN_VC['log_ALQM2mes_LV_M_VC_21'])
    # We find the names of the features chosen by RFE
    rfe_VC_features = [f for (f, support) in zip(quant_variables_VC + dummy_variables, rfe_VC.support_) if support]

    # We store and append the score of the regression to the empty list score_VC
    R2 = rfe_VC.score(standardized_vars_VC, df_noBCN_VC['log_ALQM2mes_LV_M_VC_21'])
    score_VC.append(R2)
    # We append the adjusted R squared to the empty list adjusted_R_squared_VC
    adjusted_R_squared_VC.append(adjusted_R2(R2 = R2, n = len(df_noBCN_VC), p = n))
    
    # We print the desired results
    print('Chosen VC features for', n, 'features:', rfe_VC_features)
    print('RFE score (R^2) with the training data for', n, 'features:', rfe_VC.score(standardized_vars_VC, df_noBCN_VC['log_ALQM2mes_LV_M_VC_21']))

print('Highest adjusted R^2 is given for:', np.argmax(adjusted_R_squared_VC) + 1, 'features, with a a score of', np.max(adjusted_R_squared_VC))

plt.plot(list(range(1, len(quant_variables_VC + dummy_variables) + 1)), score_VC, color = 'blue')
plt.plot(list(range(1, len(quant_variables_VC + dummy_variables) + 1)), adjusted_R_squared_VC, color = 'crimson')
plt.legend(['R^2', 'Adjusted R^2'])
plt.xlabel('Number of features selected with RFE')
plt.ylabel('Score of the linear regression')
plt.title('Score of the linear regression for n selected features - collective dwellings')
plt.show()
# Out:
# Chosen VC features for 1 features: ['time_priv_trans']
# RFE score (R^2) with the training data for 1 features: 0.4358188940720633
# Chosen VC features for 2 features: ['time_priv_trans', 'log_avg_inc_hh']
# RFE score (R^2) with the training data for 2 features: 0.7353148129857118
# Chosen VC features for 3 features: ['time_priv_trans', 'log_avg_inc_hh', 'ratio_rented_houses_population']
# RFE score (R^2) with the training data for 3 features: 0.8706944923668481
# Chosen VC features for 4 features: ['time_priv_trans', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_tram']
# RFE score (R^2) with the training data for 4 features: 0.8788276872121419
# Chosen VC features for 5 features: ['time_priv_trans', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 5 features: 0.8834045830230015
# Chosen VC features for 6 features: ['time_priv_trans', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 6 features: 0.8886860307754691
# Chosen VC features for 7 features: ['time_priv_trans', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 7 features: 0.9209440879134141
# Chosen VC features for 8 features: ['time_priv_trans', 'foreign_born_rate', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 8 features: 0.9275174949195261
# Chosen VC features for 9 features: ['time_priv_trans', 'foreign_born_rate', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 9 features: 0.932065294113667
# Chosen VC features for 10 features: ['time_priv_trans', 'foreign_born_rate', 'superior_studies_rate', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 10 features: 0.932444695631216
# Chosen VC features for 11 features: ['time_priv_trans', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 11 features: 0.93435682741066
# Chosen VC features for 12 features: ['time_priv_trans', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 12 features: 0.9347813809732267
# Chosen VC features for 13 features: ['time_priv_trans', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 13 features: 0.93490086199097
# Chosen VC features for 14 features: ['time_priv_trans', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 14 features: 0.9352805721184668
# Chosen VC features for 15 features: ['time_priv_trans', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 15 features: 0.9375907207428942
# Chosen VC features for 16 features: ['time_priv_trans', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 16 features: 0.9383980909594548
# Chosen VC features for 17 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 17 features: 0.9385301293094149
# Chosen VC features for 18 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# RFE score (R^2) with the training data for 18 features: 0.9386315624308261
# Chosen VC features for 19 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# RFE score (R^2) with the training data for 19 features: 0.939282063626523
# Chosen VC features for 20 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# RFE score (R^2) with the training data for 20 features: 0.9393814821517102
# Chosen VC features for 21 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# RFE score (R^2) with the training data for 21 features: 0.9394101788442665
# Chosen VC features for 22 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# RFE score (R^2) with the training data for 22 features: 0.9394163812261425
# Chosen VC features for 23 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# RFE score (R^2) with the training data for 23 features: 0.939417114697817
# Chosen VC features for 24 features: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# RFE score (R^2) with the training data for 24 features: 0.9394174953811797
# Highest adjusted R^2 is given for: 9 features, with a a score of 0.9076087999945871

# %%
# SINGLE-FAMILY DWELLINGS

## In these empty lists I will save the score of each regression and the adjusted R-squared
score_VU = []
adjusted_R_squared_VU = []

for n in range(1, len(quant_variables_VU + dummy_variables) + 1):
    rfe_VU = RFE(mlr_VU, n_features_to_select = n)
    # We perform RFE for the explanatory and dependent variables
    rfe_VU.fit(standardized_vars_VU, df_noBCN_VU['log_ALQM2mes_LV_M_VU_21'])
    # We find the names of the features chosen by RFE
    rfe_VU_features = [f for (f, support) in zip(quant_variables_VU + dummy_variables, rfe_VU.support_) if support]
    
    # We store and append the score of the regression to the empty list score_VU
    R2 = rfe_VU.score(standardized_vars_VU, df_noBCN_VU['log_ALQM2mes_LV_M_VU_21'])
    score_VU.append(R2)
    # We append the adjusted R squared to the empty list adjusted_R_squared_VU
    adjusted_R_squared_VU.append(adjusted_R2(R2 = R2, n = len(df_noBCN_VU), p = n))

    # We print the desired results
    print('Chosen VU features for', n, 'features:', rfe_VU_features)
    print('RFE score (R^2) with the training data for', n, 'features:', rfe_VU.score(standardized_vars_VU, df_noBCN_VU['log_ALQM2mes_LV_M_VU_21']))

print('Highest adjusted R^2 is given for:', np.argmax(adjusted_R_squared_VU) + 1, 'features, with a a score of', np.max(adjusted_R_squared_VU))

plt.plot(list(range(1, len(quant_variables_VU + dummy_variables) + 1)), score_VU, color = 'blue')
plt.plot(list(range(1, len(quant_variables_VU + dummy_variables) + 1)), adjusted_R_squared_VU, color = 'crimson')
plt.legend(['R^2', 'Adjusted R^2'])
plt.xlabel('Number of features selected with RFE')
plt.ylabel('Score of the linear regression')
plt.title('Score of the linear regression for n selected features - single-family dwellings')
plt.show()
# Out:
# Chosen VU features for 1 features: ['log_avg_inc_hh']
# RFE score (R^2) with the training data for 1 features: 0.2478648212894934
# Chosen VU features for 2 features: ['foreign_born_rate', 'log_avg_inc_hh']
# RFE score (R^2) with the training data for 2 features: 0.4872140970785719
# Chosen VU features for 3 features: ['foreign_born_rate', 'log_avg_inc_hh', 'has_beach']
# RFE score (R^2) with the training data for 3 features: 0.4906002968405543
# Chosen VU features for 4 features: ['foreign_born_rate', 'superior_studies_rate', 'log_avg_inc_hh', 'has_beach']
# RFE score (R^2) with the training data for 4 features: 0.4907326598416528
# Chosen VU features for 5 features: ['foreign_born_rate', 'superior_studies_rate', 'vpo', 'log_avg_inc_hh', 'has_beach']
# RFE score (R^2) with the training data for 5 features: 0.5868640360658719
# Chosen VU features for 6 features: ['foreign_born_rate', 'superior_studies_rate', 'vpo', 'log_avg_inc_hh', 'has_beach', 'has_metro']
# RFE score (R^2) with the training data for 6 features: 0.5977840469023181
# Chosen VU features for 7 features: ['str_line_dist', 'foreign_born_rate', 'superior_studies_rate', 'vpo', 'log_avg_inc_hh', 'has_beach', 'has_metro']
# RFE score (R^2) with the training data for 7 features: 0.6993373813392438
# Chosen VU features for 8 features: ['time_priv_trans', 'str_line_dist', 'foreign_born_rate', 'superior_studies_rate', 'vpo', 'log_avg_inc_hh', 'has_beach', 'has_metro']
# RFE score (R^2) with the training data for 8 features: 0.7130598255226047
# Chosen VU features for 9 features: ['time_priv_trans', 'str_line_dist', 'foreign_born_rate', 'superior_studies_rate', 'vpo', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_beach', 'has_metro']
# RFE score (R^2) with the training data for 9 features: 0.7601586241804613
# Chosen VU features for 10 features: ['time_priv_trans', 'str_line_dist', 'foreign_born_rate', 'superior_studies_rate', 'vpo', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_metro']
# RFE score (R^2) with the training data for 10 features: 0.7646041385442558
# Chosen VU features for 11 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'vpo', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_metro']
# RFE score (R^2) with the training data for 11 features: 0.7848845148299766
# Chosen VU features for 12 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_metro']
# RFE score (R^2) with the training data for 12 features: 0.7863246253920384
# Chosen VU features for 13 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_metro']
# RFE score (R^2) with the training data for 13 features: 0.8101424119450438
# Chosen VU features for 14 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 14 features: 0.8138875722099218
# Chosen VU features for 15 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# RFE score (R^2) with the training data for 15 features: 0.8663186680271292
# Chosen VU features for 16 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# RFE score (R^2) with the training data for 16 features: 0.8729259139709883
# Chosen VU features for 17 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# RFE score (R^2) with the training data for 17 features: 0.8782769013101286
# Chosen VU features for 18 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# RFE score (R^2) with the training data for 18 features: 0.8922991582703378
# Chosen VU features for 19 features: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# RFE score (R^2) with the training data for 19 features: 0.8955017224224094
# Chosen VU features for 20 features: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# RFE score (R^2) with the training data for 20 features: 0.898012196034705
# Chosen VU features for 21 features: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# RFE score (R^2) with the training data for 21 features: 0.9046558350293682
# Chosen VU features for 22 features: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# RFE score (R^2) with the training data for 22 features: 0.9135468202816527
# Chosen VU features for 23 features: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# RFE score (R^2) with the training data for 23 features: 0.9139228212814408
# Chosen VU features for 24 features: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# RFE score (R^2) with the training data for 24 features: 0.9143466585590025
# Highest adjusted R^2 is given for: 18 features, with a a score of 0.7630581481947432

# %% [markdown]
# ### ii. **Sequential Forward Floating Selection**

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# %% [markdown]
# Again, **the score that is saved by SFFS will be the R^2** ("If None (default), uses 'accuracy' for sklearn classifiers and 'r2' for sklearn regressors" - https://rasbt.github.io/mlxtend/api_subpackages/mlxtend.feature_selection/).

# %%
# COLLECTIVE DWELLINGS

## In these empty lists I will save the score of each regression and the adjusted R-squared
score_VC = []
adjusted_R_squared_VC = []

# Number of features to be added
n_features = len(quant_variables_VC + dummy_variables)

# I will perform SFFS for n features (we have 24 explanatory variables overall)
sffs_VC = SFS(mlr_VC, k_features = n_features, forward = True, floating = True, cv = 0)
# We perform SFFS for the explanatory and dependent variables
sffs_VC.fit(standardized_vars_VC, df_noBCN_VC['log_ALQM2mes_LV_M_VC_21'])

# Assuming quant_variables_VC + dummy_variables contains the original feature names
original_feature_names = quant_variables_VC + dummy_variables

# We find the names of the features chosen by SFFS after n features are added. Below, this for loop is explained by ChatGPT.
for n in range(1, n_features + 1):
    selected_feature_indices = sffs_VC.subsets_[n]['feature_names']
    selected_feature_names = [original_feature_names[int(index)] for index in selected_feature_indices]
    print('Features chosen after', n, 'features are added:', selected_feature_names) 

# We print and append the score after n features are added to the empty list score_VC
for n in range(1, n_features + 1):
    R2 = sffs_VC.subsets_[n]['avg_score']
    score_VC.append(R2)
    print('Score (R^2) of the model after', n, 'features are added:', sffs_VC.subsets_[n]['avg_score'])
    # We append the adjusted R squared to the empty list adjusted_R_squared_VC
    adjusted_R_squared_VC.append(adjusted_R2(R2 = R2, n = len(df_noBCN_VC), p = n))

print('Highest adjusted R^2 is given for:', np.argmax(adjusted_R_squared_VC) + 1, 'features, with a a score of', np.max(adjusted_R_squared_VC))

plt.plot(list(range(1, n_features + 1)), score_VC, color = 'blue')
plt.plot(list(range(1, n_features + 1)), adjusted_R_squared_VC, color = 'crimson')
plt.legend(['R^2', 'Adjusted R^2'])
plt.xlabel('Number of features selected with SFFS')
plt.ylabel('Score of the linear regression')
plt.title('Score of the linear regression for n selected features - collective dwellings')
plt.show()
# Out:
# Features chosen after 1 features are added: ['time_priv_trans']
# Features chosen after 2 features are added: ['time_priv_trans', 'superior_studies_rate']
# Features chosen after 3 features are added: ['time_priv_trans', 'superior_studies_rate', 'ratio_rented_houses_population']
# Features chosen after 4 features are added: ['time_priv_trans', 'superior_studies_rate', 'mob_estud', 'ratio_rented_houses_population']
# Features chosen after 5 features are added: ['time_priv_trans', 'superior_studies_rate', 'mob_estud', 'ratio_rented_houses_population', 'has_tram']
# Features chosen after 6 features are added: ['time_priv_trans', 'superior_studies_rate', 'mob_estud', 'ratio_rented_houses_population', 'has_tram', 'has_metro']
# Features chosen after 7 features are added: ['time_priv_trans', 'superior_studies_rate', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_tram', 'has_metro']
# Features chosen after 8 features are added: ['time_priv_trans', 'foreign_born_rate', 'superior_studies_rate', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_tram', 'has_metro']
# Features chosen after 9 features are added: ['time_priv_trans', 'foreign_born_rate', 'superior_studies_rate', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 10 features are added: ['time_priv_trans', 'foreign_born_rate', 'superior_studies_rate', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 11 features are added: ['time_priv_trans', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 12 features are added: ['time_priv_trans', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 13 features are added: ['time_priv_trans', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 14 features are added: ['time_priv_trans', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 15 features are added: ['time_priv_trans', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 16 features are added: ['time_priv_trans', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 17 features are added: ['time_priv_trans', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 18 features are added: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 19 features are added: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 20 features are added: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 21 features are added: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 22 features are added: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 23 features are added: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 24 features are added: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Score (R^2) of the model after 1 features are added: 0.4358188940720633
# Score (R^2) of the model after 2 features are added: 0.7536817536023919
# Score (R^2) of the model after 3 features are added: 0.8594315353451285
# Score (R^2) of the model after 4 features are added: 0.8941972135409894
# Score (R^2) of the model after 5 features are added: 0.908922116316552
# Score (R^2) of the model after 6 features are added: 0.9132799186109711
# Score (R^2) of the model after 7 features are added: 0.9165917311482303
# Score (R^2) of the model after 8 features are added: 0.9212678376853989
# Score (R^2) of the model after 9 features are added: 0.9278640337755868
# Score (R^2) of the model after 10 features are added: 0.932444695631216
# Score (R^2) of the model after 11 features are added: 0.93435682741066
# Score (R^2) of the model after 12 features are added: 0.9356744954980577
# Score (R^2) of the model after 13 features are added: 0.9366672276636162
# Score (R^2) of the model after 14 features are added: 0.9375284518806423
# Score (R^2) of the model after 15 features are added: 0.937704352268267
# Score (R^2) of the model after 16 features are added: 0.9380617598975995
# Score (R^2) of the model after 17 features are added: 0.9388930099870653
# Score (R^2) of the model after 18 features are added: 0.9391390779300407
# Score (R^2) of the model after 19 features are added: 0.939282063626523
# Score (R^2) of the model after 20 features are added: 0.9393814821517102
# Score (R^2) of the model after 21 features are added: 0.9394101788442665
# Score (R^2) of the model after 22 features are added: 0.9394163812261425
# Score (R^2) of the model after 23 features are added: 0.939417114697817
# Score (R^2) of the model after 24 features are added: 0.9394174953811797
# Highest adjusted R^2 is given for: 10 features, with a a score of 0.9042966521442227

# %% [markdown]
# Explanation by ChatGPT of the for loop above for extracting the names of the chosen features:
# - Let's break down the second line within the loop:
#     *selected_feature_indices = sffs_VC.subsets_[n]['feature_names']*
#
#     In this line, *sffs_VC.subsets_[n]['feature_names']* is retrieving the feature names associated with the current subset after adding n features. This appears to be stored as a tuple of strings, where each string represents an index.
# - Now, let's break down the list comprehension in the next line:
#     *selected_feature_names = [original_feature_names[int(index)] for index in selected_feature_indices]*
#
#     - *original_feature_names[int(index)]*: This part is taking each index from selected_feature_indices and converting it to an integer (*int(index)*).
#
#     - f*or index in selected_feature_indices*: This part is iterating over each index in selected_feature_indices, which is the list of indices obtained from the current subset.
#
#     - The entire list comprehension creates a new list *selected_feature_names* where each element is the corresponding feature name retrieved from *original_feature_names* using the adjusted index.
#
# In summary, this line is mapping the indices obtained from the feature selection process to the actual feature names in your original list original_feature_names. It ensures that the feature names are correctly matched with the selected indices.

# %%
# SINGLE-FAMILY DWELLINGS

## In these empty lists I will save the score of each regression and the adjusted R-squared
score_VU = []
adjusted_R_squared_VU = []

# Number of features to be added
n_features = len(quant_variables_VU + dummy_variables)

# I will perform SFFS for n features (we have 24 explanatory variables overall)
sffs_VU = SFS(mlr_VU, k_features = n_features, forward = True, floating = True, cv = 0)
# We perform SFFS for the explanatory and dependent variables
sffs_VU.fit(standardized_vars_VU, df_noBCN_VU['log_ALQM2mes_LV_M_VU_21'])

# Assuming quant_variables_VU + dummy_variables contains the original feature names
original_feature_names = quant_variables_VU + dummy_variables

# We find the names of the features chosen by SFFS after n features are added. Below, this for loop is explained by ChatGPT.
for n in range(1, n_features + 1):
    selected_feature_indices = sffs_VU.subsets_[n]['feature_names']
    selected_feature_names = [original_feature_names[int(index)] for index in selected_feature_indices]
    print('Features chosen after', n, 'features are added:', selected_feature_names) 

# We print and append the score after n features are added to the empty list score_VU
for n in range(1, n_features + 1):
    R2 = sffs_VU.subsets_[n]['avg_score']
    score_VU.append(R2)
    print('Score (R^2) of the model after', n, 'features are added:', sffs_VU.subsets_[n]['avg_score'])
    # We append the adjusted R squared to the empty list adjusted_R_squared_VU
    adjusted_R_squared_VU.append(adjusted_R2(R2 = R2, n = len(df_noBCN_VU), p = n))

print('Highest adjusted R^2 is given for:', np.argmax(adjusted_R_squared_VU) + 1, 'features, with a a score of', np.max(adjusted_R_squared_VU))

plt.plot(list(range(1, n_features + 1)), score_VU, color = 'blue')
plt.plot(list(range(1, n_features + 1)), adjusted_R_squared_VU, color = 'crimson')
plt.legend(['R^2', 'Adjusted R^2'])
plt.xlabel('Number of features selected with SFFS')
plt.ylabel('Score of the linear regression')
plt.title('Score of the linear regression for n selected features - single-family dwellings')
plt.show()
# Out:
# Features chosen after 1 features are added: ['superior_studies_rate']
# Features chosen after 2 features are added: ['superior_studies_rate', 'log_pop_density']
# Features chosen after 3 features are added: ['superior_studies_rate', 'new_houses', 'log_pop_density']
# Features chosen after 4 features are added: ['superior_studies_rate', 'new_houses', 'log_pop_density', 'has_parks']
# Features chosen after 5 features are added: ['superior_studies_rate', 'ibi_urb', 'new_houses', 'log_pop_density', 'has_parks']
# Features chosen after 6 features are added: ['superior_studies_rate', 'ibi_urb', 'new_houses', 'log_pop_density', 'has_parks', 'has_tram']
# Features chosen after 7 features are added: ['superior_studies_rate', 'ibi_urb', 'new_houses', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram']
# Features chosen after 8 features are added: ['superior_studies_rate', 'ibi_urb', 'vpo', 'new_houses', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram']
# Features chosen after 9 features are added: ['superior_studies_rate', 'ibi_urb', 'vpo', 'new_houses', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram']
# Features chosen after 10 features are added: ['foreign_born_rate', 'superior_studies_rate', 'ibi_urb', 'vpo', 'new_houses', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram']
# Features chosen after 11 features are added: ['foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'vpo', 'new_houses', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram']
# Features chosen after 12 features are added: ['foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'vpo', 'new_houses', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_fgc']
# Features chosen after 13 features are added: ['foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'vpo', 'new_houses', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro', 'has_fgc']
# Features chosen after 14 features are added: ['foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro', 'has_fgc']
# Features chosen after 15 features are added: ['str_line_dist', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro', 'has_fgc']
# Features chosen after 16 features are added: ['str_line_dist', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_fgc']
# Features chosen after 17 features are added: ['str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_fgc']
# Features chosen after 18 features are added: ['str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_fgc']
# Features chosen after 19 features are added: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_fgc']
# Features chosen after 20 features are added: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_fgc']
# Features chosen after 21 features are added: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 22 features are added: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 23 features are added: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 24 features are added: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Score (R^2) of the model after 1 features are added: 0.2843515740619633
# Score (R^2) of the model after 2 features are added: 0.4902554562525058
# Score (R^2) of the model after 3 features are added: 0.5361135755581887
# Score (R^2) of the model after 4 features are added: 0.6205083614371096
# Score (R^2) of the model after 5 features are added: 0.6596788258364423
# Score (R^2) of the model after 6 features are added: 0.7069497870902298
# Score (R^2) of the model after 7 features are added: 0.7381630885029513
# Score (R^2) of the model after 8 features are added: 0.776950543240097
# Score (R^2) of the model after 9 features are added: 0.7939137246062743
# Score (R^2) of the model after 10 features are added: 0.8040372942083701
# Score (R^2) of the model after 11 features are added: 0.8148798149892011
# Score (R^2) of the model after 12 features are added: 0.8264899684573622
# Score (R^2) of the model after 13 features are added: 0.8379680315026669
# Score (R^2) of the model after 14 features are added: 0.8488443271104913
# Score (R^2) of the model after 15 features are added: 0.8529588143871758
# Score (R^2) of the model after 16 features are added: 0.8687300477055687
# Score (R^2) of the model after 17 features are added: 0.879156502706874
# Score (R^2) of the model after 18 features are added: 0.8872406216333653
# Score (R^2) of the model after 19 features are added: 0.8971258510632246
# Score (R^2) of the model after 20 features are added: 0.9036563794010857
# Score (R^2) of the model after 21 features are added: 0.9075834080886587
# Score (R^2) of the model after 22 features are added: 0.9117549692865434
# Score (R^2) of the model after 23 features are added: 0.9139228212814408
# Score (R^2) of the model after 24 features are added: 0.9143466585590025
# Highest adjusted R^2 is given for: 19 features, with a a score of 0.7575109346490294

# %% [markdown]
# ### iii. **Sequential Backward Floating Selection**

# %%
# COLLECTIVE DWELLINGS

## In these empty lists I will save the score of each regression and the adjusted R-squared
score_VC = []
adjusted_R_squared_VC = []

# Number of features to remain after SBFS
n_features = 1

# I will perform SBFS for 1 feature (i.e., we will remove all the variables until we only keep 1)
sbfs_VC = SFS(mlr_VC, k_features = n_features, forward = False, floating = True, cv = 0)
# We perform SBFS for the explanatory and dependent variables
sbfs_VC.fit(standardized_vars_VC, df_noBCN_VC['log_ALQM2mes_LV_M_VC_21'])

# Assuming quant_variables_VC + dummy_variables contains the original feature names
original_feature_names = quant_variables_VC + dummy_variables

# We find the names of the features chosen by SBFS after n features are subtracted.
for n in sbfs_VC.subsets_:
    selected_feature_indices = sbfs_VC.subsets_[n]['feature_names']
    selected_feature_names = [original_feature_names[int(index)] for index in selected_feature_indices]
    print('Features chosen after', len(quant_variables_VC + dummy_variables) - n, 'features are subtracted:', selected_feature_names) 

# We print and append the score after n features are added to the empty list score_VC
for n in sbfs_VC.subsets_:
    R2 = sbfs_VC.subsets_[n]['avg_score']
    score_VC.append(R2)
    print('Score (R^2) of the model after', len(quant_variables_VC + dummy_variables) - n, 'features are subtracted:', sbfs_VC.subsets_[n]['avg_score'])
    # We append the adjusted R squared to the empty list adjusted_R_squared_VC
    adjusted_R_squared_VC.append(adjusted_R2(R2 = R2, n = len(df_noBCN_VC), p = n))

# We reverse the order of score_VC and adjusted_R_squared_VC
score_VC = score_VC[::-1]
adjusted_R_squared_VC = adjusted_R_squared_VC[::-1]

print('Highest adjusted R^2 is given for:', (np.argmax(adjusted_R_squared_VC) + 1), 'features, with a a score of', np.max(adjusted_R_squared_VC))

plt.plot(list(range(len(quant_variables_VC + dummy_variables), 0, -1)), score_VC, color = 'blue')
plt.plot(list(range(len(quant_variables_VC + dummy_variables), 0, -1)), adjusted_R_squared_VC, color = 'crimson')
plt.legend(['R^2', 'Adjusted R^2'])
plt.xlabel('Number of subtracted features with SBFS')
plt.ylabel('Score of the linear regression')
plt.title('Score of the linear regression for n subtracted features - collective dwellings')
plt.show()
# Out:
# Features chosen after 0 features are subtracted: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 1 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 2 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 3 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 4 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 5 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 6 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 7 features are subtracted: ['time_priv_trans', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 8 features are subtracted: ['time_priv_trans', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 9 features are subtracted: ['time_priv_trans', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 10 features are subtracted: ['time_priv_trans', 'unemployment_rate', 'foreign_born_rate', 'population_growth', 'mob_estud', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_fgc']
# Features chosen after 11 features are subtracted: ['time_priv_trans', 'unemployment_rate', 'foreign_born_rate', 'population_growth', 'mob_estud', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 12 features are subtracted: ['time_priv_trans', 'foreign_born_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 13 features are subtracted: ['time_priv_trans', 'foreign_born_rate', 'population_growth', 'mob_estud', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 14 features are subtracted: ['time_priv_trans', 'foreign_born_rate', 'population_growth', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 15 features are subtracted: ['time_priv_trans', 'foreign_born_rate', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 16 features are subtracted: ['time_priv_trans', 'foreign_born_rate', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 17 features are subtracted: ['time_priv_trans', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 18 features are subtracted: ['time_priv_trans', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_parks', 'has_tram']
# Features chosen after 19 features are subtracted: ['time_priv_trans', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_tram']
# Features chosen after 20 features are subtracted: ['time_priv_trans', 'mob_estud', 'log_avg_inc_hh', 'ratio_rented_houses_population']
# Features chosen after 21 features are subtracted: ['time_priv_trans', 'log_avg_inc_hh', 'ratio_rented_houses_population']
# Features chosen after 22 features are subtracted: ['time_priv_trans', 'superior_studies_rate']
# Features chosen after 23 features are subtracted: ['time_priv_trans']
# Score (R^2) of the model after 0 features are subtracted: 0.9394174953811797
# Score (R^2) of the model after 1 features are subtracted: 0.939417114697817
# Score (R^2) of the model after 2 features are subtracted: 0.9394163812261425
# Score (R^2) of the model after 3 features are subtracted: 0.9394101788442665
# Score (R^2) of the model after 4 features are subtracted: 0.9393814821517102
# Score (R^2) of the model after 5 features are subtracted: 0.939282063626523
# Score (R^2) of the model after 6 features are subtracted: 0.9391390779300407
# Score (R^2) of the model after 7 features are subtracted: 0.9388930099870653
# Score (R^2) of the model after 8 features are subtracted: 0.9383980909594548
# Score (R^2) of the model after 9 features are subtracted: 0.9378977318984075
# Score (R^2) of the model after 10 features are subtracted: 0.9371774643003085
# Score (R^2) of the model after 11 features are subtracted: 0.9362423564177863
# Score (R^2) of the model after 12 features are subtracted: 0.9357190644337389
# Score (R^2) of the model after 13 features are subtracted: 0.9345619985014774
# Score (R^2) of the model after 14 features are subtracted: 0.9335383403430094
# Score (R^2) of the model after 15 features are subtracted: 0.932065294113667
# Score (R^2) of the model after 16 features are subtracted: 0.9275174949195261
# Score (R^2) of the model after 17 features are subtracted: 0.9209440879134141
# Score (R^2) of the model after 18 features are subtracted: 0.915786919738528
# Score (R^2) of the model after 19 features are subtracted: 0.9098466961986211
# Score (R^2) of the model after 20 features are subtracted: 0.8950226747149065
# Score (R^2) of the model after 21 features are subtracted: 0.8706944923668481
# Score (R^2) of the model after 22 features are subtracted: 0.7536817536023919
# Score (R^2) of the model after 23 features are subtracted: 0.4358188940720633
# Highest adjusted R^2 is given for: 9 features, with a a score of 0.9076087999945871

# %%
# SINGLE-FAMILY DWELLINGS

## In these empty lists I will save the score of each regression and the adjusted R-squared
score_VU = []
adjusted_R_squared_VU = []

# Number of features to remain after SBFS
n_features = 1

# I will perform SBFS for 1 feature (i.e., we will remove all the variables until we only keep 1)
sbfs_VU = SFS(mlr_VU, k_features = n_features, forward = False, floating = True, cv = 0)
# We perform SBFS for the explanatory and dependent variables
sbfs_VU.fit(standardized_vars_VU, df_noBCN_VU['log_ALQM2mes_LV_M_VU_21'])

# Assuming quant_variables_VU + dummy_variables contains the original feature names
original_feature_names = quant_variables_VU + dummy_variables

# We find the names of the features chosen by SBFS after n features are subtracted.
for n in sbfs_VU.subsets_:
    selected_feature_indices = sbfs_VU.subsets_[n]['feature_names']
    selected_feature_names = [original_feature_names[int(index)] for index in selected_feature_indices]
    print('Features chosen after', len(quant_variables_VU + dummy_variables) - n, 'features are subtracted:', selected_feature_names) 

# We print and append the score after n features are added to the empty list score_VU
for n in sbfs_VU.subsets_:
    R2 = sbfs_VU.subsets_[n]['avg_score']
    score_VU.append(R2)
    print('Score (R^2) of the model after', len(quant_variables_VU + dummy_variables) - n, 'features are subtracted:', sbfs_VU.subsets_[n]['avg_score'])
    # We append the adjusted R squared to the empty list adjusted_R_squared_VU
    adjusted_R_squared_VU.append(adjusted_R2(R2 = R2, n = len(df_noBCN_VU), p = n))

# We reverse the order of score_VU and adjusted_R_squared_VU
score_VU = score_VU[::-1]
adjusted_R_squared_VU = adjusted_R_squared_VU[::-1]

print('Highest adjusted R^2 is given for:', (np.argmax(adjusted_R_squared_VU) + 1), 'features, with a a score of', np.max(adjusted_R_squared_VU))

plt.plot(list(range(len(quant_variables_VU + dummy_variables), 0, -1)), score_VU, color = 'blue')
plt.plot(list(range(len(quant_variables_VU + dummy_variables), 0, -1)), adjusted_R_squared_VU, color = 'crimson')
plt.legend(['R^2', 'Adjusted R^2'])
plt.xlabel('Number of subtracted features with SBFS')
plt.ylabel('Score of the linear regression')
plt.title('Score of the linear regression for n subtracted features - single-family dwellings')
plt.show()
# Out:
# Features chosen after 0 features are subtracted: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 1 features are subtracted: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 2 features are subtracted: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 3 features are subtracted: ['time_pub_trans', 'time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 4 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies', 'has_fgc']
# Features chosen after 5 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'population_growth', 'ibi_rur', 'mob_estud', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 6 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'population_growth', 'ibi_rur', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies']
# Features chosen after 7 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'population_growth', 'ibi_rur', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 8 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'population_growth', 'ibi_rur', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 9 features are subtracted: ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'population_growth', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 10 features are subtracted: ['str_line_dist', 'pt_lines', 'foreign_born_rate', 'population_growth', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 11 features are subtracted: ['str_line_dist', 'pt_lines', 'foreign_born_rate', 'population_growth', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro']
# Features chosen after 12 features are subtracted: ['pt_lines', 'unemployment_rate', 'foreign_born_rate', 'population_growth', 'ibi_urb', 'ibi_rur', 'vpo', 'new_houses', 'parks_surface', 'has_beach', 'has_tram', 'has_rodalies']
# Features chosen after 13 features are subtracted: ['pt_lines', 'unemployment_rate', 'foreign_born_rate', 'population_growth', 'ibi_urb', 'vpo', 'new_houses', 'parks_surface', 'has_beach', 'has_tram', 'has_rodalies']
# Features chosen after 14 features are subtracted: ['unemployment_rate', 'foreign_born_rate', 'ibi_urb', 'ibi_rur', 'vpo', 'new_houses', 'parks_surface', 'has_beach', 'has_tram', 'has_rodalies']
# Features chosen after 15 features are subtracted: ['unemployment_rate', 'foreign_born_rate', 'ibi_urb', 'ibi_rur', 'vpo', 'new_houses', 'has_beach', 'has_tram', 'has_rodalies']
# Features chosen after 16 features are subtracted: ['unemployment_rate', 'foreign_born_rate', 'ibi_urb', 'ibi_rur', 'vpo', 'new_houses', 'has_beach', 'has_tram']
# Features chosen after 17 features are subtracted: ['unemployment_rate', 'foreign_born_rate', 'ibi_urb', 'vpo', 'new_houses', 'log_avg_inc_hh', 'has_tram']
# Features chosen after 18 features are subtracted: ['unemployment_rate', 'foreign_born_rate', 'ibi_urb', 'vpo', 'new_houses', 'has_tram']
# Features chosen after 19 features are subtracted: ['unemployment_rate', 'foreign_born_rate', 'ibi_urb', 'vpo', 'has_tram']
# Features chosen after 20 features are subtracted: ['unemployment_rate', 'foreign_born_rate', 'ibi_urb', 'vpo']
# Features chosen after 21 features are subtracted: ['unemployment_rate', 'foreign_born_rate', 'ibi_urb']
# Features chosen after 22 features are subtracted: ['unemployment_rate', 'log_pop_density']
# Features chosen after 23 features are subtracted: ['unemployment_rate']
# Score (R^2) of the model after 0 features are subtracted: 0.9143466585590025
# Score (R^2) of the model after 1 features are subtracted: 0.9139782608614282
# Score (R^2) of the model after 2 features are subtracted: 0.9135468202816527
# Score (R^2) of the model after 3 features are subtracted: 0.9106458043848716
# Score (R^2) of the model after 4 features are subtracted: 0.9070684425197264
# Score (R^2) of the model after 5 features are subtracted: 0.9037157758078166
# Score (R^2) of the model after 6 features are subtracted: 0.901309384255535
# Score (R^2) of the model after 7 features are subtracted: 0.8978586137996669
# Score (R^2) of the model after 8 features are subtracted: 0.8950735465073302
# Score (R^2) of the model after 9 features are subtracted: 0.8905343770483463
# Score (R^2) of the model after 10 features are subtracted: 0.8810431857360619
# Score (R^2) of the model after 11 features are subtracted: 0.8653704402860776
# Score (R^2) of the model after 12 features are subtracted: 0.8588635843112404
# Score (R^2) of the model after 13 features are subtracted: 0.8493184360057014
# Score (R^2) of the model after 14 features are subtracted: 0.8364217108427299
# Score (R^2) of the model after 15 features are subtracted: 0.8272284498035771
# Score (R^2) of the model after 16 features are subtracted: 0.8039118077001205
# Score (R^2) of the model after 17 features are subtracted: 0.7889499135826598
# Score (R^2) of the model after 18 features are subtracted: 0.7599211446567292
# Score (R^2) of the model after 19 features are subtracted: 0.7186527664447315
# Score (R^2) of the model after 20 features are subtracted: 0.681289071131465
# Score (R^2) of the model after 21 features are subtracted: 0.5762058218259046
# Score (R^2) of the model after 22 features are subtracted: 0.4474786646715735
# Score (R^2) of the model after 23 features are subtracted: 0.1633674742503637
# Highest adjusted R^2 is given for: 15 features, with a a score of 0.7993130245886348

# %% [markdown]
# ### iv. **Regressions with the results from the wrapper methods**

# %% [markdown]
# Below I will make the regressions with the variables that have given the highest adjusted R-squared for each wrapper method.

# %% [markdown]
# ##### *For collective dwellings*

# %%
print('\n Results with the features from Recursive Feature Elimination:\n ')
lr(y = 'log_ALQM2mes_LV_M_VC_21', x = ['time_priv_trans', 'foreign_born_rate', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro'], df = df_noBCN_VC)

print('\n Results with the features from Sequential Forward Floating Selection:\n ')
lr(y = 'log_ALQM2mes_LV_M_VC_21', x = ['time_priv_trans', 'foreign_born_rate', 'superior_studies_rate', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro'], df = df_noBCN_VC)

print('\n Results with the features from Sequential Backward Floating Selection:\n ')
lr(y = 'log_ALQM2mes_LV_M_VC_21', x = ['time_priv_trans', 'foreign_born_rate', 'mob_estud', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_parks', 'has_tram', 'has_metro'], df = df_noBCN_VC)
# Out:
#  Results with the features from Recursive Feature Elimination:
#
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     log_ALQM2mes_LV_M_VC_21   R-squared:                       0.932
# Model:                                 OLS   Adj. R-squared:                  0.908
# Method:                      Least Squares   F-statistic:                     36.24
# Date:                     Sat, 25 Nov 2023   Prob (F-statistic):           3.75e-12
# Time:                             11:33:15   Log-Likelihood:                 64.934
# No. Observations:                       35   AIC:                            -109.9
# Df Residuals:                           25   BIC:                            -94.31
# Df Model:                                9
# Covariance Type:                       HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -1.0795      1.154     -0.935      0.350      -3.342       1.183
# time_priv_trans                   -0.0122      0.002     -5.945      0.000      -0.016      -0.008
# foreign_born_rate                  0.6484      0.403      1.608      0.108      -0.142       1.439
# mob_estud                          0.1963      0.108      1.810      0.070      -0.016       0.409
# log_avg_inc_hh                     0.3459      0.092      3.754      0.000       0.165       0.526
# log_pop_density                   -0.0208      0.019     -1.109      0.267      -0.057       0.016
# ratio_rented_houses_population     0.0230      0.015      1.497      0.134      -0.007       0.053
# has_parks                         -0.0551      0.028     -1.981      0.048      -0.110      -0.001
# has_tram                           0.0773      0.028      2.730      0.006       0.022       0.133
# has_metro                         -0.0746      0.045     -1.643      0.100      -0.163       0.014
# ==============================================================================
# Omnibus:                        1.019   Durbin-Watson:                   1.481
# Prob(Omnibus):                  0.601   Jarque-Bera (JB):                0.264
# Skew:                           0.086   Prob(JB):                        0.876
# Kurtosis:                       3.389   Cond. No.                     5.52e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 5.52e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#  Results with the features from Sequential Forward Floating Selection:
#
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     log_ALQM2mes_LV_M_VC_21   R-squared:                       0.932
# Model:                                 OLS   Adj. R-squared:                  0.904
# Method:                      Least Squares   F-statistic:                     28.41
# Date:                     Sat, 25 Nov 2023   Prob (F-statistic):           6.74e-11
# Time:                             11:33:15   Log-Likelihood:                 65.032
# No. Observations:                       35   AIC:                            -108.1
# Df Residuals:                           24   BIC:                            -90.95
# Df Model:                               10
# Covariance Type:                       HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -1.9422      3.476     -0.559      0.576      -8.755       4.871
# time_priv_trans                   -0.0124      0.002     -4.981      0.000      -0.017      -0.008
# foreign_born_rate                  0.6780      0.471      1.440      0.150      -0.245       1.601
# superior_studies_rate             -0.1664      0.659     -0.253      0.801      -1.457       1.124
# mob_estud                          0.1825      0.146      1.251      0.211      -0.103       0.468
# log_avg_inc_hh                     0.4347      0.357      1.218      0.223      -0.265       1.134
# log_pop_density                   -0.0208      0.020     -1.052      0.293      -0.060       0.018
# ratio_rented_houses_population     0.0232      0.016      1.420      0.156      -0.009       0.055
# has_parks                         -0.0600      0.038     -1.567      0.117      -0.135       0.015
# has_tram                           0.0777      0.029      2.681      0.007       0.021       0.135
# has_metro                         -0.0773      0.047     -1.629      0.103      -0.170       0.016
# ==============================================================================
# Omnibus:                        0.687   Durbin-Watson:                   1.511
# Prob(Omnibus):                  0.709   Jarque-Bera (JB):                0.108
# Skew:                           0.055   Prob(JB):                        0.948
# Kurtosis:                       3.249   Cond. No.                     1.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 1.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#  Results with the features from Sequential Backward Floating Selection:
#
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     log_ALQM2mes_LV_M_VC_21   R-squared:                       0.932
# Model:                                 OLS   Adj. R-squared:                  0.908
# Method:                      Least Squares   F-statistic:                     36.24
# Date:                     Sat, 25 Nov 2023   Prob (F-statistic):           3.75e-12
# Time:                             11:33:15   Log-Likelihood:                 64.934
# No. Observations:                       35   AIC:                            -109.9
# Df Residuals:                           25   BIC:                            -94.31
# Df Model:                                9
# Covariance Type:                       HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -1.0795      1.154     -0.935      0.350      -3.342       1.183
# time_priv_trans                   -0.0122      0.002     -5.945      0.000      -0.016      -0.008
# foreign_born_rate                  0.6484      0.403      1.608      0.108      -0.142       1.439
# mob_estud                          0.1963      0.108      1.810      0.070      -0.016       0.409
# log_avg_inc_hh                     0.3459      0.092      3.754      0.000       0.165       0.526
# log_pop_density                   -0.0208      0.019     -1.109      0.267      -0.057       0.016
# ratio_rented_houses_population     0.0230      0.015      1.497      0.134      -0.007       0.053
# has_parks                         -0.0551      0.028     -1.981      0.048      -0.110      -0.001
# has_tram                           0.0773      0.028      2.730      0.006       0.022       0.133
# has_metro                         -0.0746      0.045     -1.643      0.100      -0.163       0.014
# ==============================================================================
# Omnibus:                        1.019   Durbin-Watson:                   1.481
# Prob(Omnibus):                  0.601   Jarque-Bera (JB):                0.264
# Skew:                           0.086   Prob(JB):                        0.876
# Kurtosis:                       3.389   Cond. No.                     5.52e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 5.52e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ##### *For single-family dwellings*

# %%
print('\n Results with the features from Recursive Feature Elimination:\n ')
lr(y = 'log_ALQM2mes_LV_M_VU_21', x = ['time_priv_trans', 'str_line_dist', 'pt_lines', 'unemployment_rate', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'mob_estud', 'vpo', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_rodalies'], df = df_noBCN_VU)

print('\n Results with the features from Sequential Forward Floating Selection:\n ')
lr(y = 'log_ALQM2mes_LV_M_VU_21', x = ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'superior_studies_rate', 'population_growth', 'ibi_urb', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'log_pop_density', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro', 'has_fgc'], df = df_noBCN_VU)

print('\n Results with the features from Sequential Backward Floating Selection:\n ')
lr(y = 'log_ALQM2mes_LV_M_VU_21', x = ['time_priv_trans', 'str_line_dist', 'pt_lines', 'foreign_born_rate', 'population_growth', 'industrial_waste', 'vpo', 'new_houses', 'parks_surface', 'log_avg_inc_hh', 'ratio_rented_houses_population', 'has_beach', 'has_parks', 'has_tram', 'has_metro'], df = df_noBCN_VU)
# Out:
#  Results with the features from Recursive Feature Elimination:
#
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     log_ALQM2mes_LV_M_VU_21   R-squared:                       0.892
# Model:                                 OLS   Adj. R-squared:                  0.763
# Method:                      Least Squares   F-statistic:                     12.62
# Date:                     Sat, 25 Nov 2023   Prob (F-statistic):           5.11e-06
# Time:                             11:33:15   Log-Likelihood:                 39.491
# No. Observations:                       34   AIC:                            -40.98
# Df Residuals:                           15   BIC:                            -11.98
# Df Model:                               18
# Covariance Type:                       HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -10.5716     15.906     -0.665      0.506     -41.746      20.603
# time_priv_trans                   -0.0170      0.015     -1.121      0.262      -0.047       0.013
# str_line_dist                     -0.0299      0.038     -0.794      0.427      -0.104       0.044
# pt_lines                          -0.0196      0.010     -2.049      0.040      -0.038      -0.001
# unemployment_rate                 -3.9780      3.648     -1.090      0.276     -11.129       3.173
# foreign_born_rate                  4.1970      1.752      2.395      0.017       0.763       7.631
# superior_studies_rate             -2.9274      3.399     -0.861      0.389      -9.589       3.735
# population_growth                 -0.8350      0.589     -1.418      0.156      -1.989       0.320
# mob_estud                          0.4346      0.501      0.867      0.386      -0.548       1.417
# vpo                               -0.0091      0.007     -1.259      0.208      -0.023       0.005
# parks_surface                   1.134e-06   1.38e-06      0.820      0.412   -1.58e-06    3.84e-06
# log_avg_inc_hh                     1.3971      1.645      0.849      0.396      -1.827       4.621
# log_pop_density                   -0.1057      0.085     -1.250      0.211      -0.271       0.060
# ratio_rented_houses_population     0.0919      0.098      0.941      0.347      -0.100       0.283
# has_beach                          0.2301      0.171      1.344      0.179      -0.105       0.566
# has_parks                          0.0881      0.188      0.469      0.639      -0.280       0.456
# has_tram                           0.3256      0.214      1.520      0.129      -0.094       0.745
# has_metro                         -0.3096      0.214     -1.446      0.148      -0.729       0.110
# has_rodalies                      -0.0759      0.136     -0.559      0.576      -0.342       0.190
# ==============================================================================
# Omnibus:                        0.140   Durbin-Watson:                   1.427
# Prob(Omnibus):                  0.932   Jarque-Bera (JB):                0.292
# Skew:                          -0.129   Prob(JB):                        0.864
# Kurtosis:                       2.627   Cond. No.                     3.44e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 3.44e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#  Results with the features from Sequential Forward Floating Selection:
#
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     log_ALQM2mes_LV_M_VU_21   R-squared:                       0.897
# Model:                                 OLS   Adj. R-squared:                  0.758
# Method:                      Least Squares   F-statistic:                     9.017
# Date:                     Sat, 25 Nov 2023   Prob (F-statistic):           6.79e-05
# Time:                             11:33:15   Log-Likelihood:                 40.270
# No. Observations:                       34   AIC:                            -40.54
# Df Residuals:                           14   BIC:                            -10.01
# Df Model:                               19
# Covariance Type:                       HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -13.0388     20.132     -0.648      0.517     -52.497      26.419
# time_priv_trans                   -0.0101      0.019     -0.526      0.599      -0.048       0.027
# str_line_dist                     -0.0348      0.043     -0.811      0.417      -0.119       0.049
# pt_lines                          -0.0142      0.015     -0.972      0.331      -0.043       0.014
# foreign_born_rate                  3.2583      2.176      1.498      0.134      -1.006       7.522
# superior_studies_rate             -1.3620      3.786     -0.360      0.719      -8.782       6.058
# population_growth                 -0.7729      0.661     -1.170      0.242      -2.068       0.522
# ibi_urb                            0.0314      0.493      0.064      0.949      -0.935       0.998
# industrial_waste                 4.78e-07   4.19e-06      0.114      0.909   -7.74e-06     8.7e-06
# vpo                               -0.0079      0.007     -1.206      0.228      -0.021       0.005
# new_houses                        -0.0231      0.028     -0.837      0.403      -0.077       0.031
# parks_surface                   1.133e-06   1.08e-06      1.046      0.296   -9.91e-07    3.26e-06
# log_avg_inc_hh                     1.4932      2.012      0.742      0.458      -2.451       5.438
# log_pop_density                   -0.0301      0.094     -0.322      0.748      -0.213       0.153
# ratio_rented_houses_population     0.0736      0.103      0.716      0.474      -0.128       0.275
# has_beach                          0.1906      0.205      0.929      0.353      -0.211       0.593
# has_parks                          0.2019      0.179      1.130      0.259      -0.148       0.552
# has_tram                           0.2051      0.300      0.685      0.494      -0.382       0.792
# has_metro                         -0.3391      0.244     -1.389      0.165      -0.817       0.139
# has_fgc                           -0.0240      0.104     -0.230      0.818      -0.228       0.180
# ==============================================================================
# Omnibus:                        0.275   Durbin-Watson:                   1.662
# Prob(Omnibus):                  0.871   Jarque-Bera (JB):                0.393
# Skew:                           0.187   Prob(JB):                        0.821
# Kurtosis:                       2.629   Cond. No.                     4.00e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large,  4e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#  Results with the features from Sequential Backward Floating Selection:
#
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     log_ALQM2mes_LV_M_VU_21   R-squared:                       0.891
# Model:                                 OLS   Adj. R-squared:                  0.799
# Method:                      Least Squares   F-statistic:                     7.961
# Date:                     Sat, 25 Nov 2023   Prob (F-statistic):           3.85e-05
# Time:                             11:33:15   Log-Likelihood:                 39.214
# No. Observations:                       34   AIC:                            -46.43
# Df Residuals:                           18   BIC:                            -22.01
# Df Model:                               15
# Covariance Type:                       HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -7.2785      3.670     -1.983      0.047     -14.471      -0.086
# time_priv_trans                   -0.0068      0.014     -0.485      0.627      -0.034       0.021
# str_line_dist                     -0.0277      0.030     -0.925      0.355      -0.086       0.031
# pt_lines                          -0.0141      0.007     -1.985      0.047      -0.028      -0.000
# foreign_born_rate                  2.7244      1.187      2.295      0.022       0.398       5.051
# population_growth                 -0.7651      0.486     -1.576      0.115      -1.717       0.187
# industrial_waste                4.917e-07   4.18e-06      0.118      0.906   -7.71e-06    8.69e-06
# vpo                               -0.0064      0.004     -1.616      0.106      -0.014       0.001
# new_houses                        -0.0260      0.016     -1.656      0.098      -0.057       0.005
# parks_surface                   1.234e-06   6.09e-07      2.027      0.043    4.06e-08    2.43e-06
# log_avg_inc_hh                     0.8695      0.316      2.747      0.006       0.249       1.490
# ratio_rented_houses_population     0.0625      0.062      1.005      0.315      -0.059       0.184
# has_beach                          0.1797      0.153      1.172      0.241      -0.121       0.480
# has_parks                          0.2333      0.152      1.535      0.125      -0.065       0.531
# has_tram                           0.2272      0.183      1.239      0.215      -0.132       0.586
# has_metro                         -0.2712      0.130     -2.081      0.037      -0.527      -0.016
# ==============================================================================
# Omnibus:                        0.023   Durbin-Watson:                   1.602
# Prob(Omnibus):                  0.989   Jarque-Bera (JB):                0.167
# Skew:                           0.053   Prob(JB):                        0.920
# Kurtosis:                       2.674   Cond. No.                     8.91e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 8.91e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
