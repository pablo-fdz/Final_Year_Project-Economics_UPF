# %% [markdown]
# ## 1. Preparar los datos
# Importamos el módulo Pandas para trabajar con tablas e importamos el Excel que nos interesa (y la hoja que nos interesa). Documentación oficial de Pandas: https://pandas.pydata.org/. Al DataFrame entero lo llamaré ***df***.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_excel('/Users/pablo/Desktop/Drive pablo.fdzalb/6o curso/TFG economía/Datos/Indices_vivienda_distritosAMB.xlsx', sheet_name = 'Distritos')
df
# Out:
#      CPRO     LITPRO  CUMUN                    LITMUN   CUDIS  \
# 0       8  Barcelona   8015                  Badalona  801501
# 1       8  Barcelona   8015                  Badalona  801502
# 2       8  Barcelona   8015                  Badalona  801503
# 3       8  Barcelona   8015                  Badalona  801504
# 4       8  Barcelona   8015                  Badalona  801505
# ..    ...        ...    ...                       ...     ...
# 121     8  Barcelona   8245  Santa Coloma de Gramenet  824506
# 122     8  Barcelona   8282                     Tiana  828201
# 123     8  Barcelona   8289    Torrelles de Llobregat  828901
# 124     8  Barcelona   8301                Viladecans  830101
# 125     8  Barcelona   8301                Viladecans  830102
#
#      BI_ALVHEPCO_TVC_15  BI_ALVHEPCO_TVU_15  ALQM2mes_LV_M_VC_15  \
# 0                 424.0               115.0             7.381939
# 1                 690.0                89.0             7.267442
# ...

# %% [markdown]
# Quieres ver: cuáles son las columnas (su nombre) y qué información hay en cada columna.

# %%
# Aquí vemos el nombre de cada columna, que está dentro de una lista
columnas = df.columns.tolist()
print(columnas)

# Información sobre los valores del DataFrame / columna
print(df.info())
print(df['places_of_interest'].info())

# Para ver la clase de dato de algo concreto, se puede utilizar la función type()
print('Tipo:', type(df['places_of_interest']))
# Out:
# ['CPRO', 'LITPRO', 'CUMUN', 'LITMUN', 'CUDIS', 'BI_ALVHEPCO_TVC_15', 'BI_ALVHEPCO_TVU_15', 'ALQM2mes_LV_M_VC_15', 'ALQM2mes_LV_25_VC_15', 'ALQM2mes_LV_75_VC_15', 'ALQM2mes_LV_M_VU_15', 'ALQM2mes_LV_25_VU_15', 'ALQM2mes_LV_75_VU_15', 'ALQTBID12_M_VC_15', 'ALQTBID12_25_VC_15', 'ALQTBID12_75_VC_15', 'ALQTBID12_M_VU_15', 'ALQTBID12_25_VU_15', 'ALQTBID12_75_VU_15', 'SLVM2_M_VC_15', 'SLVM2_25_VC_15', 'SLVM2_75_VC_15', 'SLVM2_M_VU_15', 'SLVM2_25_VU_15', 'SLVM2_75_VU_15', 'BI_ALVHEPCO_TVC_16', 'BI_ALVHEPCO_TVU_16', 'ALQM2mes_LV_M_VC_16', 'ALQM2mes_LV_25_VC_16', 'ALQM2mes_LV_75_VC_16', 'ALQM2mes_LV_M_VU_16', 'ALQM2mes_LV_25_VU_16', 'ALQM2mes_LV_75_VU_16', 'ALQTBID12_M_VC_16', 'ALQTBID12_25_VC_16', 'ALQTBID12_75_VC_16', 'ALQTBID12_M_VU_16', 'ALQTBID12_25_VU_16', 'ALQTBID12_75_VU_16', 'SLVM2_M_VC_16', 'SLVM2_25_VC_16', 'SLVM2_75_VC_16', 'SLVM2_M_VU_16', 'SLVM2_25_VU_16', 'SLVM2_75_VU_16', 'BI_ALVHEPCO_TVC_17', 'BI_ALVHEPCO_TVU_17', 'ALQM2mes_LV_M_VC_17', 'ALQM2mes_LV_25_VC_17', 'ALQM2mes_LV_75_
# ...

# %% [markdown]
# Ahora voy a hacer también otro DataFrame en el que excluiré los distritos de BCN, para los casos en los que es un gran outlier. Al nuevo DataFrame lo llamaré ***df_noBCN***.

# %%
df_noBCN = df.drop(labels = df[df['LITMUN'] == 'Barcelona'].index, axis = 0)
print(df_noBCN['LITMUN'].unique())
print(df_noBCN['LITMUN'].nunique())
# Out:
# ['Badalona' 'Badia del Vallès' 'Barberà del Vallès' 'Begues'
#  'Castellbisbal' 'Castelldefels' 'Cerdanyola del Vallès' 'Cervelló'
#  'Corbera de Llobregat' 'Cornellà de Llobregat' 'Esplugues de Llobregat'
#  'Gavà' "Hospitalet de Llobregat, L'" 'Molins de Rei' 'Montcada i Reixac'
#  'Montgat' 'Pallejà' 'Palma de Cervelló, La' 'Papiol, El'
#  'Prat de Llobregat, El' 'Ripollet' 'Sant Adrià de Besòs'
#  'Sant Andreu de la Barca' 'Sant Boi de Llobregat'
#  'Sant Climent de Llobregat' 'Sant Cugat del Vallès'
#  'Sant Feliu de Llobregat' 'Sant Joan Despí' 'Sant Just Desvern'
#  'Sant Vicenç dels Horts' 'Santa Coloma de Cervelló'
#  'Santa Coloma de Gramenet' 'Tiana' 'Torrelles de Llobregat' 'Viladecans']
# 35

# %%
# Comando para que los gráficos se abran en pestañas separadas (ejecutar para figuras grandes)
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# ## 2. Análisis de los datos

# %% [markdown]
# ### Five Number Summary

# %% [markdown]
# ¿De qué variables?
# 1) De los precios
# 2) De los tiempos de desplazamiento en transporte público y privado.
# 3) Del número de líneas de transporte únicas por municipio.
# 4) Houses y rented houses (supply)
# 6) Population growth (demand)

# %% [markdown]
# #### a) Precios

# %%
print('Descripción de los precios medianos por m2 de viviendas colectivas:')
df['ALQM2mes_LV_M_VC_21'].describe()
# Out:
# Descripción de los precios medianos por m2 de viviendas colectivas:
# count    124.000000
# mean       9.996967
# std        1.663770
# min        6.353846
# 25%        8.827306
# 50%        9.734587
# 75%       11.016527
# max       15.384615
# Name: ALQM2mes_LV_M_VC_21, dtype: float64

# %%
print('Descripción de los precios medianos por m2 de viviendas unifamiliares:')
df['ALQM2mes_LV_M_VU_21'].describe()
# Out:
# Descripción de los precios medianos por m2 de viviendas unifamiliares:
# count    100.000000
# mean       7.554995
# std        2.527028
# min        2.872412
# 25%        5.805782
# 50%        6.979129
# 75%        9.019377
# max       14.072149
# Name: ALQM2mes_LV_M_VU_21, dtype: float64

# %% [markdown]
# #### b) Tiempos de desplazamiento

# %%
print('Descripción de los tiempos de desplazamiento en transporte público hasta el centro de BCN:')
df['time_pub_trans'].describe()
# Out:
# Descripción de los tiempos de desplazamiento en transporte público hasta el centro de BCN:
# count    126.000000
# mean      36.500000
# std       12.925479
# min        7.000000
# 25%       27.000000
# 50%       36.000000
# 75%       44.000000
# max       86.000000
# Name: time_pub_trans, dtype: float64

# %%
print('Descripción de los tiempos de desplazamiento en transporte privado hasta el centro de BCN:')
df['time_priv_trans'].describe()
# Out:
# Descripción de los tiempos de desplazamiento en transporte privado hasta el centro de BCN:
# count    126.000000
# mean      37.547619
# std        9.595505
# min        5.000000
# 25%       35.000000
# 50%       35.000000
# 75%       45.000000
# max       60.000000
# Name: time_priv_trans, dtype: float64

# %% [markdown]
# #### c) Líneas de transporte únicas

# %%
print('Descripción de las líneas de transporte únicas por municipio:')
df['pt_lines'].describe()
# Out:
# Descripción de las líneas de transporte únicas por municipio:
# count    126.000000
# mean      34.714286
# std       51.349447
# min        1.000000
# 25%        9.500000
# 50%       21.000000
# 75%       32.000000
# max      203.000000
# Name: pt_lines, dtype: float64

# %%
# Excluyendo BCN
print('Descripción de las líneas de transporte únicas por municipio, excluyendo BCN:')
df_noBCN['pt_lines'].describe()
# Out:
# Descripción de las líneas de transporte únicas por municipio, excluyendo BCN:
# count    116.000000
# mean      20.206897
# std       13.825318
# min        1.000000
# 25%        9.000000
# 50%       19.000000
# 75%       29.000000
# max       58.000000
# Name: pt_lines, dtype: float64

# %% [markdown]
# #### d) Houses y rented houses (supply)

# %%
print('Descripción del número total de viviendas por distrito:')
df['houses'].describe()
# Out:
# Descripción del número total de viviendas por distrito:
# count       126.000000
# mean      11845.658730
# std       22351.530086
# min         263.000000
# 25%        2438.500000
# 50%        5119.000000
# 75%        9135.000000
# max      142928.000000
# Name: houses, dtype: float64

# %%
print('Descripción del número total de hogares por distrito:')
df['households'].describe()
# Out:
# Descripción del número total de hogares por distrito:
# count       126.000000
# mean      10250.293651
# std       18576.931956
# min         230.000000
# 25%        2099.500000
# 50%        4545.000000
# 75%        8061.750000
# max      113598.000000
# Name: households, dtype: float64

# %%
print('Descripción del número total de viviendas en propiedad por distrito:')
df['owned_houses'].describe()
# Out:
# Descripción del número total de viviendas en propiedad por distrito:
# count      126.000000
# mean      6836.896825
# std      11441.187131
# min        144.000000
# 25%       1600.750000
# 50%       3367.000000
# 75%       5799.750000
# max      64910.000000
# Name: owned_houses, dtype: float64

# %%
print('Descripción del número total de viviendas en alquiler (según MITMA) por distrito:')
df['rented_houses_mitma'].describe()
# Out:
# Descripción del número total de viviendas en alquiler (según MITMA) por distrito:
# count      126.00000
# mean      1784.65873
# std       3725.10607
# min         16.00000
# 25%        252.75000
# 50%        600.50000
# 75%       1245.00000
# max      25281.00000
# Name: rented_houses_mitma, dtype: float64

# %%
print('Descripción del número total de viviendas en alquiler (según INE) por distrito:')
df['rented_houses_ine'].describe()
# Out:
# Descripción del número total de viviendas en alquiler (según INE) por distrito:
# count      126.000000
# mean      2675.380952
# std       5892.280911
# min         26.000000
# 25%        395.500000
# 50%        781.000000
# 75%       1698.000000
# max      40075.000000
# Name: rented_houses_ine, dtype: float64

# %% [markdown]
# #### e) Population growth (demand)

# %%
print('Descripción del crecimiento de la población por distrito:')
df['population_growth'].describe()
# Out:
# Descripción del crecimiento de la población por distrito:
# count    126.000000
# mean       0.121291
# std        0.429300
# min       -0.707909
# 25%       -0.018683
# 50%        0.036548
# 75%        0.148431
# max        3.450667
# Name: population_growth, dtype: float64

# %% [markdown]
# What, hay un distrito en el que ha crecido más de un 300% la población. ¿Cuál es?

# %%
df[df['population_growth'] > 3]
# Out:
#     CPRO     LITPRO  CUMUN               LITMUN   CUDIS  BI_ALVHEPCO_TVC_15  \
# 81     8  Barcelona   8194  Sant Adrià de Besòs  819404                13.0
#
#     BI_ALVHEPCO_TVU_15  ALQM2mes_LV_M_VC_15  ALQM2mes_LV_25_VC_15  \
# 81                 NaN             8.257576              6.455857
#
#     ALQM2mes_LV_75_VC_15  ...  pop_density  industrial_waste  \
# 81              10.56152  ...       9760.0           6818.75
#
#     agriculture_workers_rate  industry_workers_rate  \
# 81                       0.0               0.163749
#
#     construction_workers_rate  services_workers_rate  population_growth  \
# 81                   0.088371               0.747881           3.450667
#
#     new_houses  places_of_interest  mob_estud
# 81         7.7            0.134695    0.67691
#
# [1 rows x 186 columns]

# %% [markdown]
# ### Summary statistics for categorical data
# Tabla de frecuencias y proporciones de las dummies de has_publictransport. No incluiremos el bus porque todos tienen bus. Excluyo BCN de todos los cálculos.

# %%
print('Tabla de frecuencias de si un distrito tiene o no tranvía:')
print(df_noBCN['has_tram'].value_counts())

print('Tabla de proporciones de si un distrito tiene o no tranvía:')
print(df_noBCN['has_tram'].value_counts(normalize = True))
# Out:
# Tabla de frecuencias de si un distrito tiene o no tranvía:
# has_tram
# 0    85
# 1    31
# Name: count, dtype: int64
# Tabla de proporciones de si un distrito tiene o no tranvía:
# has_tram
# 0    0.732759
# 1    0.267241
# Name: proportion, dtype: float64

# %%
print('Tabla de frecuencias de si un distrito tiene o no metro:')
print(df_noBCN['has_metro'].value_counts())

print('Tabla de proporciones de si un distrito tiene o no metro:')
print(df_noBCN['has_metro'].value_counts(normalize = True))
# Out:
# Tabla de frecuencias de si un distrito tiene o no metro:
# has_metro
# 0    77
# 1    39
# Name: count, dtype: int64
# Tabla de proporciones de si un distrito tiene o no metro:
# has_metro
# 0    0.663793
# 1    0.336207
# Name: proportion, dtype: float64

# %%
print('Tabla de frecuencias de si un distrito tiene o no rodalies:')
print(df_noBCN['has_rodalies'].value_counts())

print('Tabla de proporciones de si un distrito tiene o no rodalies:')
print(df_noBCN['has_rodalies'].value_counts(normalize = True))
# Out:
# Tabla de frecuencias de si un distrito tiene o no rodalies:
# has_rodalies
# 0    73
# 1    43
# Name: count, dtype: int64
# Tabla de proporciones de si un distrito tiene o no rodalies:
# has_rodalies
# 0    0.62931
# 1    0.37069
# Name: proportion, dtype: float64

# %%
print('Tabla de frecuencias de si un distrito tiene o no FGC:')
print(df_noBCN['has_fgc'].value_counts())

print('Tabla de proporciones de si un distrito tiene o no FGC:')
print(df_noBCN['has_fgc'].value_counts(normalize = True))
# Out:
# Tabla de frecuencias de si un distrito tiene o no FGC:
# has_fgc
# 0    100
# 1     16
# Name: count, dtype: int64
# Tabla de proporciones de si un distrito tiene o no FGC:
# has_fgc
# 0    0.862069
# 1    0.137931
# Name: proportion, dtype: float64

# %% [markdown]
# Pie plots de las dummies anteriores.

# %%
plt.figure(figsize = (20, 20))

plt.subplot(2, 2, 1)
plt.pie([np.sum(df_noBCN['has_tram'] == 1), np.sum(df_noBCN['has_tram'] == 0)], autopct = '%0.2f%%')
plt.axis('equal')
plt.legend(['Tram', 'No tram'])

plt.subplot(2, 2, 2)
plt.pie([np.sum(df_noBCN['has_metro'] == 1), np.sum(df_noBCN['has_metro'] == 0)], autopct = '%0.2f%%')
plt.axis('equal')
plt.legend(['Metro', 'No metro'])

plt.subplot(2, 2, 3)
plt.pie([np.sum(df_noBCN['has_rodalies'] == 1), np.sum(df_noBCN['has_rodalies'] == 0)], autopct = '%0.2f%%')
plt.axis('equal')
plt.legend(['Rodalies', 'No Rodalies'])

plt.subplot(2, 2, 4)
plt.pie([np.sum(df_noBCN['has_fgc'] == 1), np.sum(df_noBCN['has_fgc'] == 0)], autopct = '%0.2f%%')
plt.axis('equal')
plt.legend(['FGC', 'No FGC'])

plt.suptitle('Observed relative frequencies of public transport in each district')
plt.show()

# %% [markdown]
# ### Boxplots (caixa i bigotis)

# %% [markdown]
# Para hacer boxplots, hay que importar la librería que se llama matplotlib. Documentación oficial de Matplotlib: https://matplotlib.org/. No ven claro que hagamos boxplots de la evolución de los precios en la AMB porque no es el point de nuestro trabajo, y el five-number summary representa mejor a nivel numérico lo que buscamos.

# %% [markdown]
# A lo mejor lo podemos hacer para las mismas variables del five-number summary, porque así veremos si hay outliers. Por ejemplo, podríamos hacer boxplots de:
# 1) Tiempos de desplazamiento
# 2) Líneas de transporte únicas.
# 3) houses, households, owned_houses y rented_houses_[mitma/ine].

# %% [markdown]
# #### a) Tiempos de desplazamiento
# Excluyo BCN.

# %%
plt.figure(figsize = (10, 10))
plt.boxplot([df_noBCN['time_pub_trans'], df_noBCN['time_priv_trans']], labels = ['Tiempo transporte público', 'Tiempo transporte privado'])
plt.title('Tiempo de desplazamiento en función del tipo de transporte')

# Ahora mostramos el gráfico. Se abrirá en una pestaña distinta por el hecho de haber puesto %matplotlib (si quieres verlo aquí abajo, hay que quitar eso).
plt.show()

# Guardamos el boxplot (quitar el # para que se ejecute).
#plt.savefig('Boxplot_fresco.png')

# %% [markdown]
# #### b) Líneas de transporte únicas
# Incluyendo y excluyendo BCN.

# %%
plt.figure(figsize = (10, 10))
plt.boxplot([df['pt_lines'], df_noBCN['pt_lines']], labels = ['Incluyendo BCN', 'Excluyendo BCN'])
plt.title('Número de líneas de transporte únicas en la AMB')
plt.show()

# %% [markdown]
# #### c) houses, households, owned_houses y rented_houses_[mitma/ine].
# Excluyendo BCN.

# %%
plt.figure(figsize = (10, 10))
plt.boxplot([df_noBCN['houses'], df_noBCN['households']], 
            labels = ['Viviendas', 'Hogares'])
plt.title('Número de viviendas y hogares por distrito en 2021')
plt.show()

# %%
plt.figure(figsize = (10, 10))
plt.boxplot([df_noBCN['rented_houses_mitma'], df_noBCN['rented_houses_ine'], df_noBCN['owned_houses']], 
            labels = ['En alquiler (MITMA)', 'En alquiler (INE)', 'En propiedad'])
plt.title('Número de viviendas en alquiler y propiedad por distrito en 2021')
plt.show()

# %%
plt.figure(figsize = (10, 10))
plt.boxplot([df_noBCN['rented_houses_mitma'], df_noBCN['rented_houses_ine']], 
            labels = ['En alquiler (MITMA)', 'En alquiler (INE)'])
plt.title('Número de viviendas en alquiler por distrito en 2021')
plt.show()

# %% [markdown]
# ### Side-by-side bar charts

# %% [markdown]
# A modo introductorio, podríamos hacer side-by-side bar charts para ver la evolución de los precios en la AMB distinguiendo de si se trata de viviendas unifamiliares y colectivas. Incluyo los datos de BCN.

# %%
# Primero voy a calcular la media de las medianas de cada distrito y para cada año de cada tipo de viviendas, creando un DataFrame para cada tipo de vivienda.
# Para calcular las medias, voy a utilizar una media ponderada, obtenida a partir del número de viviendas de cada tipo para cada distrito (en la variable
# "BI_ALVHEPCO_TVC_AA" y "BI_ALVHEPCO_TVU_AA").

## Cálculo de las medias ponderadas para las viviendas colectivas 

weights_price_VC_2015 = (df['ALQM2mes_LV_M_VC_15'] * df['BI_ALVHEPCO_TVC_15']) / df['BI_ALVHEPCO_TVC_15'].sum()
mean_price_VC_2015 = weights_price_VC_2015.sum()

weights_price_VC_2016 = (df['ALQM2mes_LV_M_VC_16'] * df['BI_ALVHEPCO_TVC_16']) / df['BI_ALVHEPCO_TVC_16'].sum()
mean_price_VC_2016 = weights_price_VC_2016.sum()

weights_price_VC_2017 = (df['ALQM2mes_LV_M_VC_17'] * df['BI_ALVHEPCO_TVC_17']) / df['BI_ALVHEPCO_TVC_17'].sum()
mean_price_VC_2017 = weights_price_VC_2017.sum()

weights_price_VC_2018 = (df['ALQM2mes_LV_M_VC_18'] * df['BI_ALVHEPCO_TVC_18']) / df['BI_ALVHEPCO_TVC_18'].sum()
mean_price_VC_2018 = weights_price_VC_2018.sum()

weights_price_VC_2019 = (df['ALQM2mes_LV_M_VC_19'] * df['BI_ALVHEPCO_TVC_19']) / df['BI_ALVHEPCO_TVC_19'].sum()
mean_price_VC_2019 = weights_price_VC_2019.sum()

weights_price_VC_2020 = (df['ALQM2mes_LV_M_VC_20'] * df['BI_ALVHEPCO_TVC_20']) / df['BI_ALVHEPCO_TVC_20'].sum()
mean_price_VC_2020 = weights_price_VC_2020.sum()

weights_price_VC_2021 = (df['ALQM2mes_LV_M_VC_21'] * df['BI_ALVHEPCO_TVC_21']) / df['BI_ALVHEPCO_TVC_21'].sum()
mean_price_VC_2021 = weights_price_VC_2021.sum()

## Cálculo de las medias ponderadas para las viviendas unifamiliares 

weights_price_VU_2015 = (df['ALQM2mes_LV_M_VU_15'] * df['BI_ALVHEPCO_TVU_15']) / df['BI_ALVHEPCO_TVU_15'].sum()
mean_price_VU_2015 = weights_price_VU_2015.sum()

weights_price_VU_2016 = (df['ALQM2mes_LV_M_VU_16'] * df['BI_ALVHEPCO_TVU_16']) / df['BI_ALVHEPCO_TVU_16'].sum()
mean_price_VU_2016 = weights_price_VU_2016.sum()

weights_price_VU_2017 = (df['ALQM2mes_LV_M_VU_17'] * df['BI_ALVHEPCO_TVU_17']) / df['BI_ALVHEPCO_TVU_17'].sum()
mean_price_VU_2017 = weights_price_VU_2017.sum()

weights_price_VU_2018 = (df['ALQM2mes_LV_M_VU_18'] * df['BI_ALVHEPCO_TVU_18']) / df['BI_ALVHEPCO_TVU_18'].sum()
mean_price_VU_2018 = weights_price_VU_2018.sum()

weights_price_VU_2019 = (df['ALQM2mes_LV_M_VU_19'] * df['BI_ALVHEPCO_TVU_19']) / df['BI_ALVHEPCO_TVU_19'].sum()
mean_price_VU_2019 = weights_price_VU_2019.sum()

weights_price_VU_2020 = (df['ALQM2mes_LV_M_VU_20'] * df['BI_ALVHEPCO_TVU_20']) / df['BI_ALVHEPCO_TVU_20'].sum()
mean_price_VU_2020 = weights_price_VU_2020.sum()

weights_price_VU_2021 = (df['ALQM2mes_LV_M_VU_21'] * df['BI_ALVHEPCO_TVU_21']) / df['BI_ALVHEPCO_TVU_21'].sum()
mean_price_VU_2021 = weights_price_VU_2021.sum()

## Creación de un DataFrame con las medias para cada año

mean_prices = {'Year': [2015, 2016, 2017, 2018, 2019, 2020, 2021],
                  'Mean_prices_VC': [mean_price_VC_2015, mean_price_VC_2016, mean_price_VC_2017, mean_price_VC_2018, mean_price_VC_2019, mean_price_VC_2020, mean_price_VC_2021],
                  'Mean_prices_VU': [mean_price_VU_2015, mean_price_VU_2016, mean_price_VU_2017, mean_price_VU_2018, mean_price_VU_2019, mean_price_VU_2020, mean_price_VU_2021]}

df_mean_prices = pd.DataFrame(mean_prices)
df_mean_prices
# Out:
#    Year  Mean_prices_VC  Mean_prices_VU
# 0  2015        8.973307        6.464505
# 1  2016        9.172566        6.737850
# 2  2017        9.554390        7.016451
# 3  2018       10.150536        7.311330
# 4  2019       10.964409        7.957239
# 5  2020       11.224037        7.921647
# 6  2021       11.405342        8.207607

# %%
# Ahora voy a crear el side-by-side bar chart
## Primero, determinaré la posición de cada barra en el gráfico
### Datos viviendas colectivas
n = 1
t = 2
d = df_mean_prices['Year'].count()
w = 0.8
x_values1 = [t * element + w * n for element in range(d)]

### Datos viviendas unifamiliares
n = 2
t = 2
d = df_mean_prices['Year'].count()
w = 0.8
x_values2 = [t * element + w * n for element in range(d)]

## Ahora creamos los dos gráficos
plt.figure(figsize = (10,8))
ax = plt.subplot()
plt.bar(x_values1, df_mean_prices['Mean_prices_VC'], color = 'crimson')
plt.bar(x_values2, df_mean_prices['Mean_prices_VU'], color = 'blue')

### Ponemos títulos, leyendas y demás
plt.legend(['Collective', 'Single-family'])
plt.xlabel('Year')
plt.ylabel('Median price (€/m2)')
#plt.title('Median prices for collective and single-family dwellings in the AMB')

### Ajustamos las x-ticks y los nombres para que sean los años
middle_x = [(a + b) / 2.0 for a, b in zip(x_values1, x_values2)]
ax.set_xticks(middle_x)
ax.set_xticklabels(df_mean_prices['Year'])

plt.show()

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Sería interesante hacer histogramas de:
# 1) Mediana de precios / m2 de viviendas unifamiliares y colectivas.
# 2) Tiempos de desplazamiento (en transporte público y privado). Excluiré BCN.
# 3) ¿Líneas de transporte únicas? Excluiré BCN.

# %% [markdown]
# #### a) Precios

# %%
# Viviendas colectivas
plt.hist(df['ALQM2mes_LV_M_VC_21'], bins = 14)
plt.xlabel('€ / m2')
plt.ylabel('Frecuencia')
plt.title('Precio por m2 de viviendas colectivas en el 2021')
plt.show()

# %%
# Viviendas unifamiliares
plt.hist(df['ALQM2mes_LV_M_VU_21'], bins = 20)
plt.xlabel('€ / m2')
plt.ylabel('Frecuencia')
plt.title('Precio por m2 de viviendas unifamiliares en el 2021')
plt.show()

# %% [markdown]
# #### b) Tiempos de desplazamiento
# Excluyo los datos de BCN.

# %%
# En transporte público
plt.hist(df_noBCN['time_pub_trans'], bins = 10)
plt.xlabel('mins')
plt.ylabel('Frecuencia')
plt.title('Tiempo de desplazamiento en transporte público al centro de BCN por distrito')
plt.show()

# %%
# En transporte privado
plt.hist(df_noBCN['time_priv_trans'], bins = 8)
plt.xlabel('mins')
plt.ylabel('Frecuencia')
plt.title('Tiempo de desplazamiento en transporte privado al centro de BCN por distrito')
plt.show()

# %% [markdown]
# #### c) Líneas de transporte únicas
# Excluyo los datos de BCN.

# %%
plt.hist(df_noBCN.groupby('CUMUN').pt_lines.mean(), bins = 10)
plt.xlabel('Número de líneas')
plt.ylabel('Frecuencia')
plt.title('Número de líneas de transporte únicas por municipio')
plt.show()

# %% [markdown]
# ### Overlapping Histograms

# %% [markdown]
# Con estos histogramas podemos comparar la distribución entre una variable y otra.
#
# Para que las dos variables en el histograma sean comparables, hay que usar el parámetro "density = True" para que el eje vertical sea una densidad en vez de una frecuencia, de manera que los dos histogramas sean comparables aunque no tengan la misma frecuencia. Por otro lado, perdemos cierta interpretabilidad del eje y. Aun así, por lo que se ve abajo en el caso de los precios no vale la pena: las frecuencias son muy similares por lo que se pueden comparar las dos distribuciones.
#
# Puede estar bien poner una línea de contorno al histograma para distinguir mejor las distribuciones.

# %%
# Con contorno
plt.hist(df['ALQM2mes_LV_M_VU_21'], color = 'blue', label = 'Single-family', density = False, alpha = 0.5, bins = 12, histtype='step', fill = True, edgecolor = 'Aqua', linewidth = 1.5)
plt.hist(df['ALQM2mes_LV_M_VC_21'], color = 'crimson', label = 'Collective', density = False, alpha = 0.5, bins = 12, histtype='step', fill = True, edgecolor = 'Red', linewidth = 1.5)
plt.xlabel('€ / m2')
plt.ylabel('Frequency')
#plt.title('Median prices per m2 for collective and single-family dwellings in 2021')
plt.legend()
plt.show()

# %% [markdown]
# Test de distribuciones normales.

# %%
from scipy.stats import skewtest

statistic, pvalue = skewtest(df['ALQM2mes_LV_M_VC_21'], axis = 0, nan_policy = 'omit')
print(pvalue)
# Out:
# 0.006214865617771203

# %% [markdown]
# ### Scatter plots

# %% [markdown]
# De qué los podemos hacer (combinaciones entre las variables de abajo, tanto entre variables dependientes como explicativas para temas de multicolinearidad):
# 1) Precios medianos.
# 2) Tiempos de desplazamiento (privado y transporte público).
# 3) Distancia en línea recta a BCN.
# 4) Socioeconómicas (sobre todo, entre sí):
#     a) Impuestos locales.
#     b) Variables de estudios.
#     c) Inmigración.
#     d) Sectores económicos (pensar si quitamos una variable para evitar multicolinearidad).
#     e) Average income.
# 5) Real estate characteristics (entre sí y con precios):
#     a) Número de viviendas.
#     b) Número de viviendas alquiladas y en propiedad.
#     c) Número de viviendas acabadas en 2021.
#
# Pondré especial énfasis en los 3 primeros grupos de variables, ya que son el foco de nuestro trabajo.
#
# **Para todos utilizaré los datos que excluyen a BCN (df_noBCN)**.

# %% [markdown]
# #### a) Precios
# Entre sí y con otras variables.

# %% [markdown]
# ##### i) Precios entre sí

# %%
plt.scatter(x = df_noBCN['ALQM2mes_LV_M_VU_21'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('Precio mediano de las viviendas unifamiliares (€/m2)')
plt.ylabel('Precio mediano de las viviendas colectivas (€/m2)')
plt.show()

# %% [markdown]
# ##### ii) Viviendas colectivas

# %%
# 1. Figura para las variables de tiempo de desplazamiento y distancia en línea recta.
# El eje y representará, en todo caso, ALQM2mes_LV_M_VC_21 (Precio mediano de las viviendas colectivas (€/m2)).

plt.figure(figsize = (20, 20/3))

# Creamos el primer subplot, con time_pub_trans
plt.subplot(2, 3, 1)
plt.scatter(x = df_noBCN['time_pub_trans'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('time_pub_trans')

# Creamos el segundo subplot, con time_priv_trans
plt.subplot(2, 3, 2)
plt.scatter(x = df_noBCN['time_priv_trans'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('time_priv_trans')

# Creamos el tercer subplot, con str_line_dist
plt.subplot(2, 3, 3)
plt.scatter(x = df_noBCN['str_line_dist'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('str_line_dist')

plt.subplot(2, 3, 4)

plt.subplot(2, 3, 5)

plt.subplot(2, 3, 6)

plt.suptitle('Precio mediano de las viviendas colectivas (€/m2) y variables de desplazamiento y distancia en línea recta')
plt.show()

# %%
# 2. Figura para las variables socioeconómicas más relevantes.
plt.figure(figsize = (30, 30))

plt.subplot(3, 4, 1)
plt.scatter(x = df_noBCN['population'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('population')

plt.subplot(3, 4, 2)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 4, 3)
plt.scatter(x = df_noBCN['foreign_born_rate'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('foreign_born_rate')

plt.subplot(3, 4, 4)
plt.scatter(x = df_noBCN['now_studying_univ_rate'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('now_studying_univ_rate')

plt.subplot(3, 4, 5)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplot(3, 4, 6)
plt.scatter(x = df_noBCN['industry_workers_rate'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('industry_workers_rate')

plt.subplot(3, 4, 7)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('construction_workers_rate')

plt.subplot(3, 4, 8)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('services_workers_rate')

plt.subplot(3, 4, 10)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

plt.subplot(3, 4, 11)
plt.scatter(x = df_noBCN['ibi_urb'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('ibi_urb')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Precio mediano de las viviendas colectivas (€/m2) y variables socioeconómicas')
plt.show()

# %%
# 3. Figura para las real estate characteristics más relevantes.

plt.figure(figsize = (20, 20))

plt.subplot(2, 3, 1)
plt.scatter(x = df_noBCN['houses'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('houses')

plt.subplot(2, 3, 2)
plt.scatter(x = df_noBCN['households'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('households')

plt.subplot(2, 3, 3)
plt.scatter(x = df_noBCN['owned_houses'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('owned_houses')

plt.subplot(2, 3, 4)
plt.scatter(x = df_noBCN['rented_houses_ine'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('rented_houses_ine')

plt.subplot(2, 3, 5)
plt.scatter(x = df_noBCN['rented_houses_mitma'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('rented_houses_mitma')

plt.subplot(2, 3, 6)
plt.scatter(x = df_noBCN['new_houses'], y = df_noBCN['ALQM2mes_LV_M_VC_21'], alpha = 0.6)
plt.xlabel('new_houses')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Precio mediano de las viviendas colectivas (€/m2) y real estate characteristics')
plt.show()

# %% [markdown]
# ##### iii) Viviendas unifamiliares
# Utilizaré las mismas variables y código que para las viviendas colectivas.

# %%
# 1. Figura para las variables de tiempo de desplazamiento y distancia en línea recta.
# El eje y representará, en todo caso, ALQM2mes_LV_M_VU_21 (Precio mediano de las viviendas unifamiliares (€/m2)).

plt.figure(figsize = (20, 8))

# Creamos el primer subplot, con time_pub_trans
plt.subplot(2, 3, 1)
plt.scatter(x = df_noBCN['time_pub_trans'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('time_pub_trans')

# Creamos el segundo subplot, con time_priv_trans
plt.subplot(2, 3, 2)
plt.scatter(x = df_noBCN['time_priv_trans'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('time_priv_trans')

# Creamos el tercer subplot, con str_line_dist
plt.subplot(2, 3, 3)
plt.scatter(x = df_noBCN['str_line_dist'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('str_line_dist')

plt.subplot(2, 3, 4)

plt.subplot(2, 3, 5)

plt.subplot(2, 3, 6)

plt.suptitle('Precio mediano de las viviendas unifamiliares (€/m2) y variables de desplazamiento y distancia en línea recta')
plt.show()

# %%
# 2. Figura para las variables socioeconómicas más relevantes.

plt.figure(figsize = (30, 30))

plt.subplot(3, 4, 1)
plt.scatter(x = df_noBCN['population'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('population')

plt.subplot(3, 4, 2)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 4, 3)
plt.scatter(x = df_noBCN['foreign_born_rate'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('foreign_born_rate')

plt.subplot(3, 4, 4)
plt.scatter(x = df_noBCN['now_studying_univ_rate'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('now_studying_univ_rate')

plt.subplot(3, 4, 5)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplot(3, 4, 6)
plt.scatter(x = df_noBCN['industry_workers_rate'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('industry_workers_rate')

plt.subplot(3, 4, 7)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('construction_workers_rate')

plt.subplot(3, 4, 8)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('services_workers_rate')

plt.subplot(3, 4, 10)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

plt.subplot(3, 4, 11)
plt.scatter(x = df_noBCN['ibi_urb'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('ibi_urb')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Precio mediano de las viviendas unifamiliares (€/m2) y variables socioeconómicas')
plt.show()

# %%
# 3. Figura para las real estate characteristics más relevantes.

plt.figure(figsize = (20, 20))

plt.subplot(2, 3, 1)
plt.scatter(x = df_noBCN['houses'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('houses')

plt.subplot(2, 3, 2)
plt.scatter(x = df_noBCN['households'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('households')

plt.subplot(2, 3, 3)
plt.scatter(x = df_noBCN['owned_houses'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('owned_houses')

plt.subplot(2, 3, 4)
plt.scatter(x = df_noBCN['rented_houses_ine'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('rented_houses_ine')

plt.subplot(2, 3, 5)
plt.scatter(x = df_noBCN['rented_houses_mitma'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('rented_houses_mitma')

plt.subplot(2, 3, 6)
plt.scatter(x = df_noBCN['new_houses'], y = df_noBCN['ALQM2mes_LV_M_VU_21'], alpha = 0.6)
plt.xlabel('new_houses')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Precio mediano de las viviendas unifamiliares (€/m2) y real estate characteristics')
plt.show()

# %% [markdown]
# #### b) Tiempos de desplazamiento
# Entre sí y con otras variables distintas de los precios.

# %% [markdown]
# ##### i) Entre sí

# %%
# Si el tráfico fuera fluido y cuanto más lejos estuviera un municipio, peores
# conexiones tuviera tanto en transporte privado como en transporte público (y
# al revés para municipios cercanos), deberíamos de observar una correlación 
# positiva. Ahora bien, ¿es así?

plt.scatter(x = df_noBCN['time_pub_trans'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('Tiempo de desplazamiento en transporte público (mins)')
plt.ylabel('Tiempo de desplazamiento en transporte privado (mins)')
plt.show()

# ¡Parece que no hay peligro de multicolinearidad! La hipótesis de arriba
# no se verifica del todo.

# %% [markdown]
# ##### ii) Tiempo de desplazamiento en transporte público

# %%
# 1. Con la distancia en línea recta.

plt.scatter(x = df_noBCN['str_line_dist'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('Distancia en línea recta (km)')
plt.ylabel('Tiempo de desplazamiento en transporte público (mins)')
plt.show()

# ¡Parece que HAY peligro de multicolinearidad!

# %%
# 2. Figura para las variables socioeconómicas más relevantes.
# El eje y representará, en todo caso, time_pub_trans (Tiempo de desplazamiento en transporte público (mins)).

plt.figure(figsize = (30, 30))

plt.subplot(3, 4, 1)
plt.scatter(x = df_noBCN['population'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('population')

plt.subplot(3, 4, 2)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 4, 3)
plt.scatter(x = df_noBCN['foreign_born_rate'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('foreign_born_rate')

plt.subplot(3, 4, 4)
plt.scatter(x = df_noBCN['now_studying_univ_rate'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('now_studying_univ_rate')

plt.subplot(3, 4, 5)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplot(3, 4, 6)
plt.scatter(x = df_noBCN['industry_workers_rate'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('industry_workers_rate')

plt.subplot(3, 4, 7)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('construction_workers_rate')

plt.subplot(3, 4, 8)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('services_workers_rate')

plt.subplot(3, 4, 10)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

plt.subplot(3, 4, 11)
plt.scatter(x = df_noBCN['ibi_urb'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('ibi_urb')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Tiempo de desplazamiento en transporte público (mins) y variables socioeconómicas')
plt.show()

# %%
# 3. Figura para las real estate characteristics más relevantes.

plt.figure(figsize = (20, 20))

plt.subplot(2, 3, 1)
plt.scatter(x = df_noBCN['houses'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('houses')

plt.subplot(2, 3, 2)
plt.scatter(x = df_noBCN['households'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('households')

plt.subplot(2, 3, 3)
plt.scatter(x = df_noBCN['owned_houses'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('owned_houses')

plt.subplot(2, 3, 4)
plt.scatter(x = df_noBCN['rented_houses_ine'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('rented_houses_ine')

plt.subplot(2, 3, 5)
plt.scatter(x = df_noBCN['rented_houses_mitma'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('rented_houses_mitma')

plt.subplot(2, 3, 6)
plt.scatter(x = df_noBCN['new_houses'], y = df_noBCN['time_pub_trans'], alpha = 0.6)
plt.xlabel('new_houses')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Tiempo de desplazamiento en transporte público (mins) y real estate characteristics')
plt.show()

# %% [markdown]
# ##### iii) Tiempo de desplazamiento en transporte privado

# %%
# Con la distancia en línea recta.

plt.scatter(x = df_noBCN['str_line_dist'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('Distancia en línea recta (km)')
plt.ylabel('Tiempo de desplazamiento en transporte privado (mins)')
plt.show()

# ¡Parece que HAY peligro de multicolinearidad!

# %%
# 2. Figura para las variables socioeconómicas más relevantes.
# El eje y representará, en todo caso, time_priv_trans (Tiempo de desplazamiento en transporte privado (mins)).

plt.figure(figsize = (30, 30))

plt.subplot(3, 4, 1)
plt.scatter(x = df_noBCN['population'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('population')

plt.subplot(3, 4, 2)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 4, 3)
plt.scatter(x = df_noBCN['foreign_born_rate'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('foreign_born_rate')

plt.subplot(3, 4, 4)
plt.scatter(x = df_noBCN['now_studying_univ_rate'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('now_studying_univ_rate')

plt.subplot(3, 4, 5)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplot(3, 4, 6)
plt.scatter(x = df_noBCN['industry_workers_rate'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('industry_workers_rate')

plt.subplot(3, 4, 7)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('construction_workers_rate')

plt.subplot(3, 4, 8)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('services_workers_rate')

plt.subplot(3, 4, 10)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

plt.subplot(3, 4, 11)
plt.scatter(x = df_noBCN['ibi_urb'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('ibi_urb')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Tiempo de desplazamiento en transporte privado (mins) y variables socioeconómicas')
plt.show()

# %%
# 3. Figura para las real estate characteristics más relevantes.

plt.figure(figsize = (20, 20))

plt.subplot(2, 3, 1)
plt.scatter(x = df_noBCN['houses'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('houses')

plt.subplot(2, 3, 2)
plt.scatter(x = df_noBCN['households'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('households')

plt.subplot(2, 3, 3)
plt.scatter(x = df_noBCN['owned_houses'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('owned_houses')

plt.subplot(2, 3, 4)
plt.scatter(x = df_noBCN['rented_houses_ine'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('rented_houses_ine')

plt.subplot(2, 3, 5)
plt.scatter(x = df_noBCN['rented_houses_mitma'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('rented_houses_mitma')

plt.subplot(2, 3, 6)
plt.scatter(x = df_noBCN['new_houses'], y = df_noBCN['time_priv_trans'], alpha = 0.6)
plt.xlabel('new_houses')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Tiempo de desplazamiento en transporte privado (mins) y real estate characteristics')
plt.show()

# %% [markdown]
# #### c) Distancia en línea recta
# Con otras variables distintas de los precios y de los tiempos de desplazamiento (ver arriba).

# %%
# 1. Figura para las variables socioeconómicas más relevantes.
# El eje y representará, en todo caso, str_line_dist (Distancia en línea recta (km)).

plt.figure(figsize = (30, 30))

plt.subplot(3, 4, 1)
plt.scatter(x = df_noBCN['population'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('population')

plt.subplot(3, 4, 2)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 4, 3)
plt.scatter(x = df_noBCN['foreign_born_rate'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('foreign_born_rate')

plt.subplot(3, 4, 4)
plt.scatter(x = df_noBCN['now_studying_univ_rate'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('now_studying_univ_rate')

plt.subplot(3, 4, 5)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplot(3, 4, 6)
plt.scatter(x = df_noBCN['industry_workers_rate'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('industry_workers_rate')

plt.subplot(3, 4, 7)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('construction_workers_rate')

plt.subplot(3, 4, 8)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('services_workers_rate')

plt.subplot(3, 4, 10)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

plt.subplot(3, 4, 11)
plt.scatter(x = df_noBCN['ibi_urb'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('ibi_urb')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Distancia en línea recta (km) y variables socioeconómicas')
plt.show()

# %%
# 2. Figura para las real estate characteristics más relevantes.

plt.figure(figsize = (20, 20))

plt.subplot(2, 3, 1)
plt.scatter(x = df_noBCN['houses'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('houses')

plt.subplot(2, 3, 2)
plt.scatter(x = df_noBCN['households'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('households')

plt.subplot(2, 3, 3)
plt.scatter(x = df_noBCN['owned_houses'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('owned_houses')

plt.subplot(2, 3, 4)
plt.scatter(x = df_noBCN['rented_houses_ine'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('rented_houses_ine')

plt.subplot(2, 3, 5)
plt.scatter(x = df_noBCN['rented_houses_mitma'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('rented_houses_mitma')

plt.subplot(2, 3, 6)
plt.scatter(x = df_noBCN['new_houses'], y = df_noBCN['str_line_dist'], alpha = 0.6)
plt.xlabel('new_houses')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Distancia en línea recta (km) y real estate characteristics')
plt.show()

# %% [markdown]
# #### d) Socioeconómicas
# Especialmente entre sí, y con otras variables distintas de los precios. Lo miraré para las variables:
#     a) Impuestos locales.
#     b) Variables de estudios.
#     c) Inmigración.
#     d) Sectores económicos (pensar si quitamos una variable para evitar multicolinearidad).
#     e) Average income.

# %% [markdown]
# ##### i) Impuestos locales

# %%
# ibi_urb y ibi_rur

plt.scatter(x = df_noBCN['ibi_rur'], y = df_noBCN['ibi_urb'], alpha = 0.6)
plt.xlabel('IBI rural')
plt.ylabel('IBI urbano')
plt.show()

# Como ambos no están para nada correlacionados, utilizaré en adelante solo 
# el ibi_urb.

# %%
# ibi_urb con otras variables socioeconómicas con las que puede haber correlaciones
# (ibi_urb en el eje y para todos los gráficos)

plt.figure(figsize = (20, 20))

plt.subplot(2, 2, 1)
plt.scatter(x = df_noBCN['population'], y = df_noBCN['ibi_urb'], alpha = 0.6)
plt.xlabel('population')

plt.subplot(2, 2, 2)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['ibi_urb'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplot(2, 2, 3)
plt.scatter(x = df_noBCN['immigrants_rate'], y = df_noBCN['ibi_urb'], alpha = 0.6)
plt.xlabel('immigrants_rate')

plt.subplot(2, 2, 4)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['ibi_urb'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

plt.suptitle('IBI urbano y variables socioeconómicas')
plt.show()

# %% [markdown]
# ##### ii) Variables de estudios

# %%
# Entre sí (las 3 variables de estudios que hay)
plt.figure(figsize = (20, 20))

plt.subplot(2, 2, 1)
plt.scatter(x = df_noBCN['now_studying_univ_rate'], y = df_noBCN['now_studying_superior_rate'], alpha = 0.6)
plt.xlabel('now_studying_univ_rate')
plt.ylabel('now_studying_superior_rate')

plt.subplot(2, 2, 2)
plt.scatter(x = df_noBCN['superior_studies_rate'], y = df_noBCN['now_studying_superior_rate'], alpha = 0.6)
plt.xlabel('superior_studies_rate')
plt.ylabel('now_studying_superior_rate')

plt.subplot(2, 2, 3)
plt.scatter(x = df_noBCN['superior_studies_rate'], y = df_noBCN['now_studying_univ_rate'], alpha = 0.6)
plt.xlabel('superior_studies_rate')
plt.ylabel('now_studying_univ_rate')


plt.suptitle('Variables de estudios')
plt.show()

# ¡Especialmente elevada correlación en el primer gráfico!

# %%
# Ahora voy a mirar la asociación de otras variables socioeconómicas con superior_studies_rate (eje y)

plt.figure(figsize = (30, 30))

plt.subplot(3, 3, 1)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['superior_studies_rate'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 3, 2)
plt.scatter(x = df_noBCN['immigrants_rate'], y = df_noBCN['superior_studies_rate'], alpha = 0.6)
plt.xlabel('immigrants_rate')

plt.subplot(3, 3, 3)
plt.scatter(x = df_noBCN['foreign_born_rate'], y = df_noBCN['superior_studies_rate'], alpha = 0.6)
plt.xlabel('foreign_born_rate')

plt.subplot(3, 3, 4)
plt.scatter(x = df_noBCN['industry_workers_rate'], y = df_noBCN['superior_studies_rate'], alpha = 0.6)
plt.xlabel('industry_workers_rate')

plt.subplot(3, 3, 5)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['superior_studies_rate'], alpha = 0.6)
plt.xlabel('construction_workers_rate')

plt.subplot(3, 3, 6)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['superior_studies_rate'], alpha = 0.6)
plt.xlabel('services_workers_rate')

plt.subplot(3, 3, 7)
plt.scatter(x = df_noBCN['avg_inc_hh'], y = df_noBCN['superior_studies_rate'], alpha = 0.6)
plt.xlabel('avg_inc_hh')

plt.subplot(3, 3, 8)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['superior_studies_rate'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

plt.subplot(3, 3, 9)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['superior_studies_rate'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Proporción de personas con estudios superiores y variables socioeconómicas')
plt.show()

# Elevada asociación con unemployment_rate y los dos average incomes.

# %% [markdown]
# ##### iii) Inmigración

# %%
# Entre sí (las dos variables de inmigración)

plt.scatter(x = df_noBCN['immigrants_rate'], y = df_noBCN['foreign_born_rate'], alpha = 0.6)
plt.xlabel('immigrants_rate')
plt.ylabel('foreign_born_rate')
plt.show()

# Claramente hay multicolinearidad: deberíamos utilizar una o la otra. En los 
# siguientes gráficos, utilizaré solo immigrants_rate.

# %%
# Ahora voy a mirar la asociación de otras variables socioeconómicas con immigrants_rate (eje y)

plt.figure(figsize = (30, 30))

plt.subplot(3, 3, 1)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['immigrants_rate'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 3, 2)
plt.scatter(x = df_noBCN['now_studying_superior_rate'], y = df_noBCN['immigrants_rate'], alpha = 0.6)
plt.xlabel('now_studying_superior_rate')

plt.subplot(3, 3, 3)
plt.scatter(x = df_noBCN['superior_studies_rate'], y = df_noBCN['immigrants_rate'], alpha = 0.6)
plt.xlabel('superior_studies_rate')

plt.subplot(3, 3, 4)
plt.scatter(x = df_noBCN['industry_workers_rate'], y = df_noBCN['immigrants_rate'], alpha = 0.6)
plt.xlabel('industry_workers_rate')

plt.subplot(3, 3, 5)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['immigrants_rate'], alpha = 0.6)
plt.xlabel('construction_workers_rate')

plt.subplot(3, 3, 6)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['immigrants_rate'], alpha = 0.6)
plt.xlabel('services_workers_rate')

plt.subplot(3, 3, 7)
plt.scatter(x = df_noBCN['population_growth'], y = df_noBCN['immigrants_rate'], alpha = 0.6)
plt.xlabel('population_growth')

plt.subplot(3, 3, 8)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['immigrants_rate'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

plt.subplot(3, 3, 9)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['immigrants_rate'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Proporción de personas extranjeras por distrito y variables socioeconómicas')
plt.show()

# Posibles asociaciones con unemployment_rate y las variables de estudios

# %% [markdown]
# ##### iv) Sectores económicos

# %%
# Entre sí (las 4 variables de sectores económicos que hay)
plt.figure(figsize = (30, 30))

plt.subplot(2, 3, 1)
plt.scatter(x = df_noBCN['industry_workers_rate'], y = df_noBCN['agriculture_workers_rate'], alpha = 0.6)
plt.xlabel('industry_workers_rate')
plt.ylabel('agriculture_workers_rate')

plt.subplot(2, 3, 2)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['agriculture_workers_rate'], alpha = 0.6)
plt.xlabel('construction_workers_rate')
plt.ylabel('agriculture_workers_rate')

plt.subplot(2, 3, 3)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['agriculture_workers_rate'], alpha = 0.6)
plt.xlabel('services_workers_rate')
plt.ylabel('agriculture_workers_rate')

plt.subplot(2, 3, 4)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['industry_workers_rate'], alpha = 0.6)
plt.xlabel('construction_workers_rate')
plt.ylabel('industry_workers_rate')

plt.subplot(2, 3, 5)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['industry_workers_rate'], alpha = 0.6)
plt.xlabel('services_workers_rate')
plt.ylabel('industry_workers_rate')

plt.subplot(2, 3, 6)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['construction_workers_rate'], alpha = 0.6)
plt.xlabel('services_workers_rate')
plt.ylabel('construction_workers_rate')

plt.suptitle('Variables de sector económico')
plt.show()

# Hay una clara asociación lineal entre el 5o gráfico (services_workers_rate con industry_workers_rate).
# Deberíamos de no considerar una de las dos variables - dejaré de considerar industry_workers_rate (por ejemplo).

# %%
# Ahora voy a mirar la asociación de otras variables socioeconómicas con services_workers_rate (eje y)

plt.figure(figsize = (30, 30))

plt.subplot(3, 3, 1)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['services_workers_rate'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 3, 2)
plt.scatter(x = df_noBCN['now_studying_superior_rate'], y = df_noBCN['services_workers_rate'], alpha = 0.6)
plt.xlabel('now_studying_superior_rate')

plt.subplot(3, 3, 3)
plt.scatter(x = df_noBCN['superior_studies_rate'], y = df_noBCN['services_workers_rate'], alpha = 0.6)
plt.xlabel('superior_studies_rate')

plt.subplot(3, 3, 4)
plt.scatter(x = df_noBCN['now_studying_univ_rate'], y = df_noBCN['services_workers_rate'], alpha = 0.6)
plt.xlabel('now_studying_univ_rate')

plt.subplot(3, 3, 5)
plt.scatter(x = df_noBCN['immigrants_rate'], y = df_noBCN['services_workers_rate'], alpha = 0.6)
plt.xlabel('immigrants_rate')

plt.subplot(3, 3, 6)
plt.scatter(x = df_noBCN['foreign_born_rate'], y = df_noBCN['services_workers_rate'], alpha = 0.6)
plt.xlabel('foreign_born_rate')

plt.subplot(3, 3, 7)
plt.scatter(x = df_noBCN['mob_estud'], y = df_noBCN['services_workers_rate'], alpha = 0.6)
plt.xlabel('population_growth')

plt.subplot(3, 3, 8)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['services_workers_rate'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

plt.subplot(3, 3, 9)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['services_workers_rate'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Proporción de personas que trabajan en servicios y variables socioeconómicas')
plt.show()

# Ninguna asociación clara

# %% [markdown]
# ##### v) Average income

# %%
# Entre sí (las dos variables de income)

plt.scatter(x = df_noBCN['avg_inc_hh'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('avg_inc_hh')
plt.ylabel('avg_inc_pers')
plt.show()

# Claramente hay multicolinearidad: deberíamos utilizar una o la otra. En los 
# siguientes gráficos, utilizaré solo avg_inc_pers.

# %%
# Ahora voy a mirar la asociación de otras variables socioeconómicas con avg_inc_pers (eje y)

plt.figure(figsize = (30, 30))

plt.subplot(3, 3, 1)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 3, 2)
plt.scatter(x = df_noBCN['now_studying_superior_rate'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('now_studying_superior_rate')

plt.subplot(3, 3, 3)
plt.scatter(x = df_noBCN['superior_studies_rate'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('superior_studies_rate')

plt.subplot(3, 3, 4)
plt.scatter(x = df_noBCN['now_studying_univ_rate'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('now_studying_univ_rate')

plt.subplot(3, 3, 5)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('construction_workers_rate')

plt.subplot(3, 3, 6)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('services_workers_rate')

plt.subplot(3, 3, 7)
plt.scatter(x = df_noBCN['population_growth'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('population_growth')

plt.subplot(3, 3, 8)
plt.scatter(x = df_noBCN['immigrants_rate'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('immigrants_rate')

plt.subplot(3, 3, 9)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['avg_inc_pers'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Ingresos medios por persona y distrito y variables socioeconómicas')
plt.show()

# Asociación bastante clara en los 4 primeros gráficos: con unemployment_rate (no lineal),
# now_studying_superior_rate, superior_studies_rate y now_studying_univ_rate (aunque en 
# menor medida en este último caso).

# %% [markdown]
# #### e) Real estate characteristics
# Especialmente entre sí, y con otras variables distintas de los precios. Lo miraré para las variables:
#     a) Número de viviendas.
#     b) Número de viviendas alquiladas y en propiedad.
#     c) Número de viviendas acabadas en 2021.

# %% [markdown]
# ##### i) Entre sí

# %%
# Entre sí (las 5 variables de sectores económicos que hay)
plt.figure(figsize = (30, 30))

plt.subplot(3, 4, 1)
plt.scatter(x = df_noBCN['households'], y = df_noBCN['houses'], alpha = 0.6)
plt.xlabel('households')
plt.ylabel('houses')

plt.subplot(3, 4, 2)
plt.scatter(x = df_noBCN['owned_houses'], y = df_noBCN['houses'], alpha = 0.6)
plt.xlabel('owned_houses')
plt.ylabel('houses')

plt.subplot(3, 4, 3)
plt.scatter(x = df_noBCN['rented_houses_mitma'], y = df_noBCN['houses'], alpha = 0.6)
plt.xlabel('rented_houses_mitma')
plt.ylabel('houses')

plt.subplot(3, 4, 4)
plt.scatter(x = df_noBCN['rented_houses_ine'], y = df_noBCN['houses'], alpha = 0.6)
plt.xlabel('rented_houses_ine')
plt.ylabel('houses')

plt.subplot(3, 4, 5)
plt.scatter(x = df_noBCN['owned_houses'], y = df_noBCN['households'], alpha = 0.6)
plt.xlabel('owned_houses')
plt.ylabel('households')

plt.subplot(3, 4, 6)
plt.scatter(x = df_noBCN['rented_houses_mitma'], y = df_noBCN['households'], alpha = 0.6)
plt.xlabel('rented_houses_mitma')
plt.ylabel('households')

plt.subplot(3, 4, 7)
plt.scatter(x = df_noBCN['rented_houses_ine'], y = df_noBCN['households'], alpha = 0.6)
plt.xlabel('rented_houses_ine')
plt.ylabel('households')

plt.subplot(3, 4, 8)
plt.scatter(x = df_noBCN['rented_houses_mitma'], y = df_noBCN['owned_houses'], alpha = 0.6)
plt.xlabel('rented_houses_mitma')
plt.ylabel('owned_houses')

plt.subplot(3, 4, 10)
plt.scatter(x = df_noBCN['rented_houses_ine'], y = df_noBCN['owned_houses'], alpha = 0.6)
plt.xlabel('rented_houses_ine')
plt.ylabel('owned_houses')

plt.subplot(3, 4, 11)
plt.scatter(x = df_noBCN['rented_houses_ine'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('rented_houses_ine')
plt.ylabel('rented_houses_mitma')

plt.subplots_adjust(hspace = 0.3, wspace = 0.4)
plt.suptitle('Variables de número de viviendas entre sí')
plt.show()

# Clara asociación lineal en casi todos los casos. Deberíamos de coger solo una variable.
# Para los siguientes análisis, utilizaré la variable rented_houses_mitma

# %% [markdown]
# ##### ii) Con variables socioeconómicas

# %%
# Ahora voy a mirar la asociación de variables socioeconómicas con rented_houses_mitma (eje y)

plt.figure(figsize = (30, 30))

plt.subplot(3, 3, 1)
plt.scatter(x = df_noBCN['population'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('population')

plt.subplot(3, 3, 2)
plt.scatter(x = df_noBCN['unemployment_rate'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('unemployment_rate')

plt.subplot(3, 3, 3)
plt.scatter(x = df_noBCN['superior_studies_rate'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('superior_studies_rate')

plt.subplot(3, 3, 4)
plt.scatter(x = df_noBCN['pop_density'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('pop_density')

plt.subplot(3, 3, 5)
plt.scatter(x = df_noBCN['construction_workers_rate'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('construction_workers_rate')

plt.subplot(3, 3, 6)
plt.scatter(x = df_noBCN['services_workers_rate'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('services_workers_rate')

plt.subplot(3, 3, 7)
plt.scatter(x = df_noBCN['avg_inc_pers'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('avg_inc_pers')

# Este gráfico representará, en teoría, una comparación entre oferta y demanda.
plt.subplot(3, 3, 8)
plt.scatter(x = df_noBCN['population_growth'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('population_growth')

plt.subplot(3, 3, 9)
plt.scatter(x = df_noBCN['ibi_urb'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('ibi_urb')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Número de viviendas en alquiler por distrito y variables socioeconómicas')
plt.show()

# Solo hay una asociación clara con population.

# %% [markdown]
# ##### iii) Con real estate characteristics

# %%
# Ahora voy a mirar la asociación de real estate characteristics con rented_houses_mitma (eje y)

plt.figure(figsize = (20, 20))

plt.subplot(2, 3, 1)
plt.scatter(x = df_noBCN['has_parks'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('has_parks')

plt.subplot(2, 3, 2)
plt.scatter(x = df_noBCN['industrial_waste'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('industrial_waste')

plt.subplot(2, 3, 3)
plt.scatter(x = df_noBCN['parks_surface'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('parks_surface')

plt.subplot(2, 3, 4)
plt.scatter(x = df_noBCN['vpo'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('vpo')

plt.subplot(2, 3, 5)
plt.scatter(x = df_noBCN['new_houses'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('new_houses')

plt.subplot(2, 3, 6)
plt.scatter(x = df_noBCN['places_of_interest'], y = df_noBCN['rented_houses_mitma'], alpha = 0.6)
plt.xlabel('places_of_interest')

plt.subplots_adjust(hspace = 0.3)
plt.suptitle('Número de viviendas en alquiler por distrito y real estate characteristics')
plt.show()

# No hay ninguna asociación clara.

# %% [markdown]
# ##### iv) Extras

# %%
# new_houses con population_growth

plt.scatter(x = df_noBCN['population_growth'], y = df_noBCN['new_houses'], alpha = 0.6)
plt.xlabel('population_growth')
plt.ylabel('new_houses')
plt.show()

# No hay ninguna asociación clara

# %% [markdown]
# ### Scatterplots con más de 2 variables
# En los que 1 variable (categórica, en este caso) pone color a los puntos. Puede servir para ver interacciones.

# %% [markdown]
# Variables con las que lo podemos hacer:
# 1) Precios con tiempos de desplazamiento y dummies de desplazamiento.
# 2) Precios con número único de líneas de transporte y dummies de desplazamiento (BCN es un gran outlier en este caso).
# 3) Precios con superficie de parques más cercanos y dummy de has_parks.
#
# **Para todos utilizaré los datos que excluyen a BCN (df_noBCN)**.

# %% [markdown]
# #### a) Precios - tiempos de desplazamiento - dummies de desplazamiento

# %% [markdown]
# ##### i) Precios de viviendas colectivas

# %%
# Eje y representa, en todos los gráficos de abajo, ALQM2mes_LV_M_VC_21 
# (precio mediano de las viviendas colectivas, en € / m2). Eje x representa,
# en todos los gráficos de abajo, time_pub_trans (Tiempo de desplazamiento en transporte público (mins)).

sns.lmplot(x = 'time_pub_trans', y = 'ALQM2mes_LV_M_VC_21', hue = 'has_tram', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'time_pub_trans', y = 'ALQM2mes_LV_M_VC_21', hue = 'has_metro', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'time_pub_trans', y = 'ALQM2mes_LV_M_VC_21', hue = 'has_rodalies', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'time_pub_trans', y = 'ALQM2mes_LV_M_VC_21', hue = 'has_fgc', fit_reg = False, data = df_noBCN)
plt.show()
# Out:
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ##### ii) Precios de viviendas unifamiliares

# %%
# Eje y representa, en todos los gráficos de abajo, ALQM2mes_LV_M_VU_21 
# (precio mediano de las viviendas unifamiliares, en € / m2). Eje x representa,
# en todos los gráficos de abajo, time_pub_trans (Tiempo de desplazamiento en transporte público (mins)).

sns.lmplot(x = 'time_pub_trans', y = 'ALQM2mes_LV_M_VU_21', hue = 'has_tram', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'time_pub_trans', y = 'ALQM2mes_LV_M_VU_21', hue = 'has_metro', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'time_pub_trans', y = 'ALQM2mes_LV_M_VU_21', hue = 'has_rodalies', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'time_pub_trans', y = 'ALQM2mes_LV_M_VU_21', hue = 'has_fgc', fit_reg = False, data = df_noBCN)
plt.show()
# Out:
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### b) Precios - líneas de transporte únicas - dummies de desplazamiento

# %% [markdown]
# ##### i) Precios de viviendas colectivas

# %%
# Eje y representa, en todos los gráficos de abajo, ALQM2mes_LV_M_VC_21 
# (precio mediano de las viviendas colectivas, en € / m2). Eje x representa,
# en todos los gráficos de abajo, pt_lines (Número de líneas de transporte únicas).

sns.lmplot(x = 'pt_lines', y = 'ALQM2mes_LV_M_VC_21', hue = 'has_tram', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'pt_lines', y = 'ALQM2mes_LV_M_VC_21', hue = 'has_metro', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'pt_lines', y = 'ALQM2mes_LV_M_VC_21', hue = 'has_rodalies', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'pt_lines', y = 'ALQM2mes_LV_M_VC_21', hue = 'has_fgc', fit_reg = False, data = df_noBCN)
plt.show()
# Out:
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ##### ii) Precios de viviendas unifamiliares

# %%
# Eje y representa, en todos los gráficos de abajo, ALQM2mes_LV_M_VU_21 
# (precio mediano de las viviendas unifamliares, en € / m2). Eje x representa,
# en todos los gráficos de abajo, pt_lines (Número de líneas de transporte únicas).

sns.lmplot(x = 'pt_lines', y = 'ALQM2mes_LV_M_VU_21', hue = 'has_tram', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'pt_lines', y = 'ALQM2mes_LV_M_VU_21', hue = 'has_metro', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'pt_lines', y = 'ALQM2mes_LV_M_VU_21', hue = 'has_rodalies', fit_reg = False, data = df_noBCN)
plt.show()

sns.lmplot(x = 'pt_lines', y = 'ALQM2mes_LV_M_VU_21', hue = 'has_fgc', fit_reg = False, data = df_noBCN)
plt.show()
# Out:
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### c) Precios - superficie de parques más cercanos - dummy has_parks

# %%
# Precio de viviendas colectivas con superficie de parques más cercanos y dummy de has_parks
sns.lmplot(x = 'parks_surface', y = 'ALQM2mes_LV_M_VC_21', hue = 'has_parks', fit_reg = False, data = df)
plt.xlabel('Superficie del parque más cercano a un distrito')
plt.ylabel('Precio mediano de las viviendas colectivas (€/m2)')
plt.show()

# Precio de viviendas unifamiliares con superficie de parques más cercanos y dummy de has_parks
sns.lmplot(x = 'parks_surface', y = 'ALQM2mes_LV_M_VU_21', hue = 'has_parks', fit_reg = False, data = df)
plt.xlabel('Superficie del parque más cercano a un distrito')
plt.ylabel('Precio mediano de las viviendas unifamiliares (€/m2)')
plt.show()
# Out:
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/pablo/miniconda3/envs/py311/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Matriz de covarianzas/correlaciones y heatmap de las correlaciones.
# Esta parte es útil, sobre todo, para ver preliminarmente cuáles son las asociaciones entre las variables y si puede haber multicolinearidad.

# %%
# Creo un nuevo DataFrame solo variables cuantitativas y que nos interesan
columns_df_noBCN2 = ['ALQM2mes_LV_M_VC_21', 'ALQM2mes_LV_M_VU_21', 'time_pub_trans', 
                     'time_priv_trans', 'str_line_dist', 'pt_lines', 'population',
                     'unemployment_rate', 'immigrants_rate', 'foreign_born_rate',
                     'now_studying_superior_rate', 'now_studying_univ_rate',
                     'superior_studies_rate', 'pop_density', 'agriculture_workers_rate',
                     'industry_workers_rate', 'construction_workers_rate', 'services_workers_rate',
                     'avg_inc_pers', 'avg_inc_hh', 'population_growth', 'ibi_urb',
                     'ibi_rur', 'mob_estud', 'houses', 'households', 'owned_houses',
                     'rented_houses_mitma', 'rented_houses_ine', 'industrial_waste',
                     'parks_surface', 'vpo', 'new_houses', 'places_of_interest']
df_noBCN2 = df_noBCN[columns_df_noBCN2]

# %% [markdown]
# Primero, creamos una matriz de correlaciones. Es una función/método de Pandas, que se puede aplicar al DataFrame entero.

# %%
# Ahora creamos la matriz de correlaciones
corr_grid = df_noBCN2.corr()
corr_grid
# Out:
#                             ALQM2mes_LV_M_VC_21  ALQM2mes_LV_M_VU_21  \
# ALQM2mes_LV_M_VC_21                    1.000000             0.658936
# ALQM2mes_LV_M_VU_21                    0.658936             1.000000
# time_pub_trans                        -0.237071             0.127397
# time_priv_trans                       -0.481265            -0.059624
# str_line_dist                         -0.324633             0.109061
# pt_lines                               0.315130            -0.142850
# population                             0.050629            -0.211174
# unemployment_rate                     -0.343621            -0.500781
# immigrants_rate                        0.394846             0.169436
# foreign_born_rate                      0.439347             0.164724
# now_studying_superior_rate             0.216461             0.443472
# now_studying_univ_rate                 0.347104             0.550445
# superior_studies_rate                  0.482919             0.636097
# ...

# %%
# Y ahora creamos un heatmap de las correlaciones con la función heatmap() de Seaborn.
# Es mejor abrirlo en una ventana nueva, que es una figura grande.
plt.figure(figsize = (40, 40))
sns.heatmap(corr_grid, xticklabels = corr_grid.columns, yticklabels = corr_grid.columns, vmin = -1, center = 0, vmax = 1, cmap = 'PuOr', annot = False)
#plt.show()
plt.savefig('correlation_heatmap.png')

# %% [markdown]
# Descubriendo las correlaciones fuertes abajo (buscando con los índices de las filas).

# %%
# For instance, for the variable ALQM2mes_LV_M_VC_21
corr_grid.iloc[0]
# Out:
# ALQM2mes_LV_M_VC_21           1.000000
# ALQM2mes_LV_M_VU_21           0.658936
# time_pub_trans               -0.237071
# time_priv_trans              -0.481265
# str_line_dist                -0.324633
# pt_lines                      0.315130
# population                    0.050629
# unemployment_rate            -0.343621
# immigrants_rate               0.394846
# foreign_born_rate             0.439347
# now_studying_superior_rate    0.216461
# now_studying_univ_rate        0.347104
# superior_studies_rate         0.482919
# pop_density                   0.293788
# agriculture_workers_rate     -0.195870
# industry_workers_rate        -0.351057
# construction_workers_rate    -0.487284
# services_workers_rate         0.534925
# avg_inc_pers                  0.515860
# avg_inc_hh                    0.492914
# population_growth             0.142426
# ibi_urb                      -0.078287
# ibi_rur                       0.014281
# mob_estud                    -0.066388
# ...

# %%
# For the variable ALQM2mes_LV_M_VU_21
corr_grid.iloc[1]
# Out:
# ALQM2mes_LV_M_VC_21           0.658936
# ALQM2mes_LV_M_VU_21           1.000000
# time_pub_trans                0.127397
# time_priv_trans              -0.059624
# str_line_dist                 0.109061
# pt_lines                     -0.142850
# population                   -0.211174
# unemployment_rate            -0.500781
# immigrants_rate               0.169436
# foreign_born_rate             0.164724
# now_studying_superior_rate    0.443472
# now_studying_univ_rate        0.550445
# superior_studies_rate         0.636097
# pop_density                  -0.028586
# agriculture_workers_rate     -0.087701
# industry_workers_rate        -0.142846
# construction_workers_rate    -0.278926
# services_workers_rate         0.243990
# avg_inc_pers                  0.681007
# avg_inc_hh                    0.696903
# population_growth             0.296715
# ibi_urb                      -0.293812
# ibi_rur                       0.117814
# mob_estud                    -0.206607
# ...

# %% [markdown]
# Explanatory / control variables with a correlation > |0.7| (multicollinearity).

# %%
columns_exp_cont = ['time_pub_trans', 
                     'time_priv_trans', 'str_line_dist', 'pt_lines', 'population',
                     'unemployment_rate', 'immigrants_rate', 'foreign_born_rate',
                     'now_studying_superior_rate', 'now_studying_univ_rate',
                     'superior_studies_rate', 'pop_density', 'agriculture_workers_rate',
                     'industry_workers_rate', 'construction_workers_rate', 'services_workers_rate',
                     'avg_inc_pers', 'avg_inc_hh', 'population_growth', 'ibi_urb',
                     'ibi_rur', 'mob_estud', 'houses', 'households', 'owned_houses',
                     'rented_houses_mitma', 'rented_houses_ine', 'industrial_waste',
                     'parks_surface', 'vpo', 'new_houses', 'places_of_interest']

for column in columns_exp_cont:
    print('Name of the column that is taken as a reference:', column)
    output = corr_grid.loc[column] >= abs(0.7)
    true_variables = output[output].index.tolist()
    print(true_variables)
# Out:
# Name of the column that is taken as a reference: time_pub_trans
# ['time_pub_trans', 'str_line_dist']
# Name of the column that is taken as a reference: time_priv_trans
# ['time_priv_trans']
# Name of the column that is taken as a reference: str_line_dist
# ['time_pub_trans', 'str_line_dist']
# Name of the column that is taken as a reference: pt_lines
# ['pt_lines', 'pop_density']
# Name of the column that is taken as a reference: population
# ['population', 'houses', 'households', 'owned_houses', 'rented_houses_mitma', 'rented_houses_ine']
# Name of the column that is taken as a reference: unemployment_rate
# ['unemployment_rate']
# Name of the column that is taken as a reference: immigrants_rate
# ['immigrants_rate', 'foreign_born_rate']
# Name of the column that is taken as a reference: foreign_born_rate
# ['immigrants_rate', 'foreign_born_rate']
# Name of the column that is taken as a reference: now_studying_superior_rate
# ...

# %% [markdown]
# Explanatory / control variables with a correlation > |0.9| (perfect multicollinearity).

# %%
for column in columns_exp_cont:
    print('Name of the column that is taken as a reference:', column)
    output = corr_grid.loc[column] >= abs(0.9)
    true_variables = output[output].index.tolist()
    print(true_variables)
# Out:
# Name of the column that is taken as a reference: time_pub_trans
# ['time_pub_trans']
# Name of the column that is taken as a reference: time_priv_trans
# ['time_priv_trans']
# Name of the column that is taken as a reference: str_line_dist
# ['str_line_dist']
# Name of the column that is taken as a reference: pt_lines
# ['pt_lines']
# Name of the column that is taken as a reference: population
# ['population', 'houses', 'households', 'owned_houses']
# Name of the column that is taken as a reference: unemployment_rate
# ['unemployment_rate']
# Name of the column that is taken as a reference: immigrants_rate
# ['immigrants_rate', 'foreign_born_rate']
# Name of the column that is taken as a reference: foreign_born_rate
# ['immigrants_rate', 'foreign_born_rate']
# Name of the column that is taken as a reference: now_studying_superior_rate
# ['now_studying_superior_rate', 'now_studying_univ_rate']
# Name of the column that is taken as a reference: now_studying_univ_rate
# ...
